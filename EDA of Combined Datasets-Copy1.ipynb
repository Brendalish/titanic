# %% [markdown]
# ## Review challenge description

# %% [markdown]
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this challenge, we are asked build a predictive model that answers the question: “what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).

# %% [markdown]
# ## Load packages, modules, data and functions

# %% [markdown]
# ### Load libraries, packages and modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
plt.style.use('fivethirtyeight')

from scipy import stats
from scipy.stats import skew

# %% [markdown]
# ### Load the two datasets and combine them
# The relationship (family member, wife-husband, child-parent, etc.) among passengers is a potential influential factor for the survival rate. For its analysis, the data of all the passengers needs to put together. So the training data and the testing data will be combined.

# %%
#load train data
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
#create a new column 'Is_train' to differentiate the training data from the testing data, 1 = training, 0 = testing
train_df['Is_train'] = 1
test_df['Is_train'] = 0
#create the 'Survived' column filled with null values in the testing data
#so as to share the same columns as the training data
test_df['Survived'] = np.nan
#combine the trainning data and testing data
full_df = pd.concat([train_df, test_df], ignore_index=True)
# delete the two dataframes which are no longer needed
del train_df, test_df
#show the first and last rows of the combined data
display(full_df.head())
full_df.tail()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Is_train
# 0      0         A/5 21171   7.2500   NaN        S         1
# 1      0          PC 17599  71.2833   C85        C         1
# 2      0  STON/O2. 3101282   7.9250   NaN        S         1
# 3      0            113803  53.1000  C123        S         1
# 4      0            373450   8.0500   NaN        S         1
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C
#
#       Is_train
# 1304         0
# 1305         0
# 1306         0
# 1307         0
# 1308         0

# %%
#Get the total number of passengers in the full dataset
len(full_df)
# Out:
# 1309

# %% [markdown]
# **Finding & analysis:**
# Our full data has 1309 records, one for each passenger. According to [WIKIPEDIA](https://en.wikipedia.org/wiki/Passengers_of_the_Titanic) and [HISTORY ON THE NET](https://www.historyonthenet.com/how-many-people-were-on-the-titanic), the total number of Titanic's passengers was 1,317 or 1316. So our full data covers 99% of the passenger population, with only 7 or 8 missing records.

# %% [markdown]
# ### Fix some data errors and fill in a couple of missing age values
#
# References:
# [Some SibSp/Parch values are wrong](https://www.kaggle.com/c/titanic/discussion/39787)
# [Miss Erna Alexandra Andersson](https://www.encyclopedia-titanica.org/titanic-survivor/erna-andersson.html)
# [Miss Ida Augusta Margareta Andersson](https://www.encyclopedia-titanica.org/titanic-victim/ida-augusta-margareta-andersson.html)

# %%
#fix the data errors according to 
#show the original records
indices = [279, 746, 1283, 987, 1188, 48, 920, 13, 610, 119, 541, 542, 813, 850, 68, 1105, 736, 436, 1058, 86, 147]
full_df.iloc[indices, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 279           280       1.0       3
# 746           747       0.0       3
# 1283         1284       NaN       3
# 987           988       NaN       1
# 1188         1189       NaN       3
# 48             49       0.0       3
# 920           921       NaN       3
# 13             14       0.0       3
# 610           611       0.0       3
# 119           120       0.0       3
# 541           542       0.0       3
# 542           543       0.0       3
# 813           814       0.0       3
# 850           851       0.0       3
# 68             69       1.0       3
# 1105         1106       NaN       3
# 736           737       0.0       3
# 436           437       0.0       3
# 1058         1059       NaN       3
# 86             87       0.0       3
# 147           148       0.0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 279                    Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      1
# 746                         Abbott, Mr. Rossmore Edward    male  16.0      1
# 1283                      Abbott, Master. Eugene Joseph    male  13.0      0
# 987   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 1188                                  Samaan, Mr. Hanna    male   NaN      2
# 48                                  Samaan, Mr. Youssef    male   NaN      2
# 920                                   Samaan, Mr. Elias    male   NaN      2
# 13                          Andersson, Mr. Anders Johan    male  39.0      1
# 610   Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 119                   Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541                Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                   Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 813                  Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850             Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 68                      Andersson, Miss. Erna Alexandra  female  17.0      4
# 1105             Andersson, Miss. Ida Augusta Margareta  female  38.0      4
# 736             Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 436                Ford, Miss. Doolina Margaret "Daisy"  female  21.0      2
# 1058                            Ford, Mr. Edward Watson    male  18.0      2
# 86                               Ford, Mr. William Neal    male  16.0      1
# 147                    Ford, Miss. Robina Maggie "Ruby"  female   9.0      2
#
#       Parch      Ticket     Fare Cabin Embarked  Is_train
# 279       1   C.A. 2673  20.2500   NaN        S         1
# 746       1   C.A. 2673  20.2500   NaN        S         1
# 1283      2   C.A. 2673  20.2500   NaN        S         0
# 987       0       19877  78.8500   C46        S         0
# 1188      0        2662  21.6792   NaN        C         0
# 48        0        2662  21.6792   NaN        C         1
# 920       0        2662  21.6792   NaN        C         0
# 13        5      347082  31.2750   NaN        S         1
# 610       5      347082  31.2750   NaN        S         1
# 119       2      347082  31.2750   NaN        S         1
# 541       2      347082  31.2750   NaN        S         1
# 542       2      347082  31.2750   NaN        S         1
# 813       2      347082  31.2750   NaN        S         1
# 850       2      347082  31.2750   NaN        S         1
# 68        2     3101281   7.9250   NaN        S         1
# 1105      2      347091   7.7750   NaN        S         0
# 736       3  W./C. 6608  34.3750   NaN        S         1
# 436       2  W./C. 6608  34.3750   NaN        S         1
# 1058      2  W./C. 6608  34.3750   NaN        S         0
# 86        3  W./C. 6608  34.3750   NaN        S         1
# 147       2  W./C. 6608  34.3750   NaN        S         1

# %%
#fix the errors and fill in the missing age values for the Sammann family
full_df.loc[279, ['SibSp', 'Parch']]= 0, 2
full_df.loc[1283, ['SibSp', 'Parch']] = 1, 1
full_df.loc[987, 'Age'] = 26
full_df.loc[1188, ['Age', 'SibSp', 'Parch']] = 40, 0, 2
full_df.loc[48, ['Age', 'SibSp', 'Parch']] = 16, 1, 1
full_df.loc[920, ['Age', 'SibSp', 'Parch']] = 18, 1, 1
full_df.loc[68, ['SibSp', 'Parch']] = 0, 0
full_df.loc[1105, ['SibSp', 'Parch']] = 0, 0
full_df.loc[736, ['SibSp', 'Parch']] = 0, 4
full_df.loc[[436, 1058, 86, 147], ['SibSp', 'Parch']] = 3, 1

# %%
#sanity check
full_df.iloc[indices, :]
# Out:
#       PassengerId  Survived  Pclass  \
# 279           280       1.0       3
# 746           747       0.0       3
# 1283         1284       NaN       3
# 987           988       NaN       1
# 1188         1189       NaN       3
# 48             49       0.0       3
# 920           921       NaN       3
# 13             14       0.0       3
# 610           611       0.0       3
# 119           120       0.0       3
# 541           542       0.0       3
# 542           543       0.0       3
# 813           814       0.0       3
# 850           851       0.0       3
# 68             69       1.0       3
# 1105         1106       NaN       3
# 736           737       0.0       3
# 436           437       0.0       3
# 1058         1059       NaN       3
# 86             87       0.0       3
# 147           148       0.0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 279                    Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0      0
# 746                         Abbott, Mr. Rossmore Edward    male  16.0      1
# 1283                      Abbott, Master. Eugene Joseph    male  13.0      1
# 987   Cavendish, Mrs. Tyrell William (Julia Florence...  female  26.0      1
# 1188                                  Samaan, Mr. Hanna    male  40.0      0
# 48                                  Samaan, Mr. Youssef    male  16.0      1
# 920                                   Samaan, Mr. Elias    male  18.0      1
# 13                          Andersson, Mr. Anders Johan    male  39.0      1
# 610   Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 119                   Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 541                Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 542                   Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 813                  Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 850             Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 68                      Andersson, Miss. Erna Alexandra  female  17.0      0
# 1105             Andersson, Miss. Ida Augusta Margareta  female  38.0      0
# 736             Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      0
# 436                Ford, Miss. Doolina Margaret "Daisy"  female  21.0      3
# 1058                            Ford, Mr. Edward Watson    male  18.0      3
# 86                               Ford, Mr. William Neal    male  16.0      3
# 147                    Ford, Miss. Robina Maggie "Ruby"  female   9.0      3
#
#       Parch      Ticket     Fare Cabin Embarked  Is_train
# 279       2   C.A. 2673  20.2500   NaN        S         1
# 746       1   C.A. 2673  20.2500   NaN        S         1
# 1283      1   C.A. 2673  20.2500   NaN        S         0
# 987       0       19877  78.8500   C46        S         0
# 1188      2        2662  21.6792   NaN        C         0
# 48        1        2662  21.6792   NaN        C         1
# 920       1        2662  21.6792   NaN        C         0
# 13        5      347082  31.2750   NaN        S         1
# 610       5      347082  31.2750   NaN        S         1
# 119       2      347082  31.2750   NaN        S         1
# 541       2      347082  31.2750   NaN        S         1
# 542       2      347082  31.2750   NaN        S         1
# 813       2      347082  31.2750   NaN        S         1
# 850       2      347082  31.2750   NaN        S         1
# 68        0     3101281   7.9250   NaN        S         1
# 1105      0      347091   7.7750   NaN        S         0
# 736       4  W./C. 6608  34.3750   NaN        S         1
# 436       1  W./C. 6608  34.3750   NaN        S         1
# 1058      1  W./C. 6608  34.3750   NaN        S         0
# 86        1  W./C. 6608  34.3750   NaN        S         1
# 147       1  W./C. 6608  34.3750   NaN        S         1

# %% [markdown]
# **More errors were found in the following analysis:**
# [two wrong_fares](#wrong_fares)

# %% [markdown]
# ### My functions

# %%
#visualization of data distribution of categorical variables
def plot_histogram(col_name, df=full_df, bins=None):
    plt.hist(df[col_name].dropna(), bins)
    plt.title('Distribution of {}'.format(col_name))
    plt.xlabel(col_name)
    plt.ylabel('Number')
    plt.show()

# %%
def compare_bars(col_name, df=full_df):
    df[df.Survived==1][col_name].dropna().\
    value_counts(normalize=False).plot(kind='bar', color='#008fd5', alpha=0.5, label='survived')
    df[df.Survived==0][col_name].dropna().\
    value_counts(normalize=False).plot(kind='bar', color='#fc4f30', alpha=0.5, label='not survived')
    plt.xticks(rotation=0)
    plt.title('Bar of {}'.format(col_name))
    plt.xlabel(col_name)
    plt.ylabel('Number')
    plt.legend(loc='upper right')
    plt.show()

# %%
def stack_bar(col_name, df=full_df):
    pd.crosstab(df[col_name], df['Survived']).plot(kind='bar', stacked=True, title='Survived by {}'.format(col_name))
    plt.xticks(rotation=0)
    pd.crosstab(df[col_name], df['Survived'], normalize='index').\
    plot(kind='bar', stacked=True,title='Survived by {} (%)'.format(col_name))
    plt.xticks(rotation=0)

# %%
def compare_hists(col_name, bins=None, df=full_df):
    plt.hist(df[df.Survived==1][col_name].dropna(), bins=bins, density=False, label='survived', alpha=0.5)
    plt.hist(df[df.Survived==0][col_name].dropna(), bins=bins, density=False, label='not survived',alpha=0.5)
    plt.title('Histograms of {}'.format(col_name))
    plt.xlabel(col_name)
    plt.ylabel('Number')
    plt.legend(loc='upper right')
    plt.show()

# %% [markdown]
# Univariate + One step ahead

# %% [markdown]
# ## Understand the variables

# %% [markdown]
# ### Overview
# <a id='2.1'></a>

# %%
#overview (number of samples and columns, column names, data types, the number of null values)
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1049 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Is_train     1309 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 133.1+ KB

# %%
isnull_sum = full_df.isnull().sum()
isnull_df = pd.concat([isnull_sum, round(isnull_sum/len(full_df)*100)], axis=1)
isnull_df.columns = ['Number', 'Percentage(%)']
isnull_df
# Out:
#              Number  Percentage(%)
# PassengerId       0            0.0
# Survived        418           32.0
# Pclass            0            0.0
# Name              0            0.0
# Sex               0            0.0
# Age             260           20.0
# SibSp             0            0.0
# Parch             0            0.0
# Ticket            0            0.0
# Fare              1            0.0
# Cabin          1014           77.0
# Embarked          2            0.0
# Is_train          0            0.0

# %% [markdown]
# **Finding:**
# Columns (except Survived) with many missing values: Age(260, 20%), Cabin(1014, 77%).
# Columns with a couple of  missing values: Fare(1), Embarked(2).

# %%
#summary statistics (check data scales and any signs of incorrect values or outliers)
full_df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1049.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.818561     0.492743
# std     378.020061    0.486592     0.837836    14.337059     1.037221
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare     Is_train
# count  1309.000000  1308.000000  1309.000000
# mean      0.381971    33.295479     0.680672
# std       0.861607    51.758668     0.466394
# min       0.000000     0.000000     0.000000
# 25%       0.000000     7.895800     0.000000
# 50%       0.000000    14.454200     1.000000
# 75%       0.000000    31.275000     1.000000
# max       9.000000   512.329200     1.000000

# %%
print('Number of zero-fare tickets:', sum(full_df.Fare==0))
# Out:
# Number of zero-fare tickets: 17

# %%
full_df[full_df.Fare==0].sort_values(by='Pclass')
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 1263         1264       NaN       1                Ismay, Mr. Joseph Bruce
# 263           264       0.0       1                  Harrison, Mr. William
# 822           823       0.0       1        Reuchlin, Jonkheer. John George
# 815           816       0.0       1                       Fry, Mr. Richard
# 1157         1158       NaN       1  Chisholm, Mr. Roderick Robert Crispin
# 633           634       0.0       1          Parr, Mr. William Henry Marsh
# 806           807       0.0       1                 Andrews, Mr. Thomas Jr
# 277           278       0.0       2            Parkes, Mr. Francis "Frank"
# 413           414       0.0       2         Cunningham, Mr. Alfred Fleming
# 466           467       0.0       2                  Campbell, Mr. William
# 481           482       0.0       2       Frost, Mr. Anthony Wood "Archie"
# 674           675       0.0       2             Watson, Mr. Ennis Hastings
# 732           733       0.0       2                   Knight, Mr. Robert J
# 179           180       0.0       3                    Leonard, Mr. Lionel
# 271           272       1.0       3           Tornquist, Mr. William Henry
# 302           303       0.0       3        Johnson, Mr. William Cahoone Jr
# 597           598       0.0       3                    Johnson, Mr. Alfred
#
#        Sex   Age  SibSp  Parch  Ticket  Fare        Cabin Embarked  Is_train
# 1263  male  49.0      0      0  112058   0.0  B52 B54 B56        S         0
# 263   male  40.0      0      0  112059   0.0          B94        S         1
# 822   male  38.0      0      0   19972   0.0          NaN        S         1
# 815   male   NaN      0      0  112058   0.0         B102        S         1
# 1157  male   NaN      0      0  112051   0.0          NaN        S         0
# 633   male   NaN      0      0  112052   0.0          NaN        S         1
# 806   male  39.0      0      0  112050   0.0          A36        S         1
# 277   male   NaN      0      0  239853   0.0          NaN        S         1
# 413   male   NaN      0      0  239853   0.0          NaN        S         1
# 466   male   NaN      0      0  239853   0.0          NaN        S         1
# 481   male   NaN      0      0  239854   0.0          NaN        S         1
# 674   male   NaN      0      0  239856   0.0          NaN        S         1
# 732   male   NaN      0      0  239855   0.0          NaN        S         1
# 179   male  36.0      0      0    LINE   0.0          NaN        S         1
# 271   male  25.0      0      0    LINE   0.0          NaN        S         1
# 302   male  19.0      0      0    LINE   0.0          NaN        S         1
# 597   male  49.0      0      0    LINE   0.0          NaN        S         1

# %% [markdown]
# **Finding & analysis on the summary statistics:**
#
# The data scales of Age and Fare are much bigger than those of the rest numerical variables. The machine-learnig algorithms based on the distance measurements or gradient descent are quite sensitive to the scales, so rescaling is necessary. For tree-based algorithms, scaling is not necessary.
#
# The minimum fare is zero, involving 17 tickets.It may indicate free tickets or missing values. [Tammy]( https://www.kaggle.com/c/titanic/discussion/10570) found the evidence about the complimentary ticket for John George. As not any evidence was found about the missing fare data marked as 0, I interpreted the value 0 as it is (free ticket).
#
# The maximum fare is 512, much higher than the median. Are there any outliers? It will be further analyzed in [Data distribution of numerical variables](#Data-distribution-of-numerical-variables)

# %%
#check the number of unique values of each columns
unique_counts = pd.DataFrame.from_records([(col, full_df[col].nunique()) for col in full_df.columns], columns=['Column_Name', 'Num_Unique']).\
                sort_values(by='Num_Unique')
unique_counts
# Out:
#     Column_Name  Num_Unique
# 1      Survived           2
# 4           Sex           2
# 12     Is_train           2
# 2        Pclass           3
# 11     Embarked           3
# 6         SibSp           7
# 7         Parch           8
# 5           Age          97
# 10        Cabin         186
# 9          Fare         281
# 8        Ticket         929
# 3          Name        1307
# 0   PassengerId        1309

# %% [markdown]
# **Finding:**
# Some categorical variables have 2 or 3 uniuqe values - 'Survived', 'Sex', 'Pclass', 'Embarked'.
# The other categorial variables have over 100 unique values - 'Cabin', 'Ticket', 'PassengerId', 'Name'. Not all the ticket numbers or cabin numbers are unique. It will be further analyzed in [Fare sharing?](#Fare-sharing?) and [Further analysis of 'Cabin' and 'Ticket'](#Further-analysis-of-'Cabin'-and-'Ticket').

# %% [markdown]
# ### Data distribution of numerical variables

# %%
#list the names of the numerical variables
cols_num = ['Age', 'SibSp', 'Parch', 'Fare']

# %%
for col in cols_num:
    skewness = skew(full_df[col].dropna())
    print('Skewness of {}: {}'.format(col, round(skewness,1)))
# Out:
# Skewness of Age: 0.4
# Skewness of SibSp: 3.9
# Skewness of Parch: 3.7
# Skewness of Fare: 4.4

# %%
#check the distribution of numerical variables
plot_histogram('Age', bins=np.arange(0, 90, 10))

# %%
plot_histogram('SibSp', bins=np.arange(0,9,1))

# %%
plot_histogram('Parch', bins=np.arange(0, 7, 1))

# %%
plot_histogram('Fare')

# %%
sns.boxplot(x='Pclass', y='Fare', data=full_df);

# %%
#obtain descriptive statistics of fares at different pclasses
fares_by_pclasses = {}
for i in range(1,4):
    fares_by_pclasses[i]=full_df.loc[full_df.Pclass==i, 'Fare'].describe()
    
fares_by_pclasses_df = pd.concat([v[1] for v in fares_by_pclasses.items()], axis=1)
fares_by_pclasses_df.columns=['Pclass ' + str(i) for i in range(1, 4)]
print("Fares' distribution in each Pclass:")
display(fares_by_pclasses_df)
# Out:
# Fares' distribution in each Pclass:
#          Pclass 1    Pclass 2    Pclass 3
# count  323.000000  277.000000  708.000000
# mean    87.508992   21.179196   13.302889
# std     80.447178   13.607122   11.494358
# min      0.000000    0.000000    0.000000
# 25%     30.695800   13.000000    7.750000
# 50%     60.000000   15.045800    8.050000
# 75%    107.662500   26.000000   15.245800
# max    512.329200   73.500000   69.550000

# %% [markdown]
# **Analysis on the distribution of numerical variables:**
#
# 'Age': relatively normal.
# 'Sibsp', 'Parch', 'Fare': not normal, right skewed. Replace them with their log, square root or inverse values may help remove the skewness and minimize the extreme values' impact on the algorithms.
#
#
# Usually, the fares are much related with the classes. It's true for this case, as confirmed by the correlation analysis in the section [Correlation between variables](#Correlation-between-variables). According to the boxplot and descriptive statistics, the fare median increases a lot (8->15->60) when the Pclass value decreases (3->2->1).
# However, it's unusual that the fares vary so much in each class (max/median 5~9) that there's considerable overlap between the fares of different classes. It's further analyzed in the the section [Fare_sharing?](#Fare-sharing?)

# %% [markdown]
# ### Data distribution of categorical variables

# %%
#List the names of the categorical columns which have fewer than 10 categories
cols_few_cat = ['Survived', 'Pclass', 'Sex', 'Embarked']
#List the names of the categorical columns which have more than 10 categories but fewer than 891 categories
cols_many_cat= ['Ticket', 'Cabin']

# %% [markdown]
# #### Categorical columns which have only a few categories

# %%
#List the value_counts of the categorical columns which have only a few categories
for col in cols_few_cat:
    print('Column Name:', col)
    print(full_df[col].value_counts(normalize=True))
    print('')
# Out:
# Column Name: Survived
# 0.0    0.616162
# 1.0    0.383838
# Name: Survived, dtype: float64
#
# Column Name: Pclass
# 3    0.541635
# 1    0.246753
# 2    0.211612
# Name: Pclass, dtype: float64
#
# Column Name: Sex
# male      0.644003
# female    0.355997
# Name: Sex, dtype: float64
#
# Column Name: Embarked
# S    0.699311
# C    0.206580
# Q    0.094109
# Name: Embarked, dtype: float64

# %% [markdown]
# #### Categorical columns which have many categories

# %%
#check for duplicated values, this 'value' means the number of samples sharing the same value, 
for col in cols_many_cat:
    value_counts = full_df[col].value_counts()
    duplicated_value_counts = value_counts.value_counts()
    duplicated_value_counts_df = duplicated_value_counts.to_frame()
    duplicated_value_counts_df.reset_index(inplace=True)
    duplicated_value_counts_df.rename(columns={'index': 'number of duplicated samples per uniuqe value', col: 'number of unique values'}, \
                                     inplace=True)
    print('Duplicated value counts of {}'.format(col))
    print(duplicated_value_counts_df)
    print('')
# Out:
# Duplicated value counts of Ticket
#    number of duplicated samples per uniuqe value  number of unique values
# 0                                              1                      713
# 1                                              2                      132
# 2                                              3                       49
# 3                                              4                       16
# 4                                              5                        7
# 5                                              7                        5
# 6                                              6                        4
# 7                                              8                        2
# 8                                             11                        1
#
# Duplicated value counts of Cabin
#    number of duplicated samples per uniuqe value  number of unique values
# 0                                              1                      107
# 1                                              2                       63
# 2                                              4                        7
# 3                                              3                        6
# 4                                              5                        2
# 5                                              6                        1

# %%
ticket_count  = full_df.Ticket.value_counts()
shared_tickets = list(ticket_count[ticket_count>1].index)
#I checked the first 30 records totally, 5 of them are shown here
full_df[full_df.Ticket.isin(shared_tickets)].sort_values(by='Ticket').head()
# Out:
#      PassengerId  Survived  Pclass  \
# 257          258       1.0       1
# 504          505       1.0       1
# 759          760       1.0       1
# 558          559       1.0       1
# 262          263       0.0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
# 262                                  Taussig, Mr. Emil    male  52.0      1
#
#      Parch  Ticket   Fare Cabin Embarked  Is_train
# 257      0  110152  86.50   B77        S         1
# 504      0  110152  86.50   B79        S         1
# 759      0  110152  86.50   B77        S         1
# 558      1  110413  79.65   E67        S         1
# 262      1  110413  79.65   E67        S         1

# %%
#I checked the first 30 records totally, 5 of them are shown here
full_df[full_df.Ticket.isin(shared_tickets)&(full_df.Pclass==3)].sort_values(by='Ticket').head()
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 74            75       1.0       3    Bing, Mr. Lee  male  32.0      0      0
# 509          510       1.0       3   Lang, Mr. Fang  male  26.0      0      0
# 838          839       1.0       3  Chip, Mr. Chang  male  32.0      0      0
# 826          827       0.0       3     Lam, Mr. Len  male   NaN      0      0
# 169          170       0.0       3    Ling, Mr. Lee  male  28.0      0      0
#
#     Ticket     Fare Cabin Embarked  Is_train
# 74    1601  56.4958   NaN        S         1
# 509   1601  56.4958   NaN        S         1
# 838   1601  56.4958   NaN        S         1
# 826   1601  56.4958   NaN        S         1
# 169   1601  56.4958   NaN        S         1

# %% [markdown]
# #### Fare sharing?
#
# On [encyclopedia-titanic](https://www.encyclopedia-titanica.org/), I found that the passengers sharing the ticket numbers are sharing the ticket fares as well, which means that the fare is actually the total fare for them.To double check, I plot the data.

# %%
#group the records by ticket numbers and count each groups
ticket_group_sizes = full_df.groupby('Ticket').size()

#create a new feature 'Ticket_group_size'    
full_df['Ticket_group_size'] = full_df['Ticket'].apply(lambda x: ticket_group_sizes[x])

# %%
#check whether the fare values within each ticket group are consistent
are_fares_different = full_df.groupby('Ticket').Fare.nunique() > 1
are_fares_different[are_fares_different].index.tolist()
# Out:
# ['7534']

# %%
full_df[full_df['Ticket']=='7534']
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 138          139       0.0       3            Osen, Mr. Olaf Elon  male  16.0
# 876          877       0.0       3  Gustafsson, Mr. Alfred Ossian  male  20.0
#
#      SibSp  Parch Ticket    Fare Cabin Embarked  Is_train  Ticket_group_size
# 138      0      0   7534  9.2167   NaN        S         1                  2
# 876      0      0   7534  9.8458   NaN        S         1                  2

# %% [markdown]
# **Finding:**
# The two fare values of ticket '7534' are only slightly different (9.2167, 9.8458).
# On [encyclopedia-titanic](https://www.encyclopedia-titanica.org/), it's not mentioned that they had any companion on board.

# %%
ticket_group_sizes = full_df['Ticket_group_size'].value_counts()
ticket_group_percentages = round(full_df['Ticket_group_size'].value_counts()/len(full_df)*100)

# %%
ticket_groups = pd.concat([ticket_group_sizes, ticket_group_percentages], axis=1)
ticket_groups.columns = ['Quantity', 'Percentage']
ticket_groups
# Out:
#     Quantity  Percentage
# 1        713        54.0
# 2        264        20.0
# 3        147        11.0
# 4         64         5.0
# 7         35         3.0
# 5         35         3.0
# 6         24         2.0
# 8         16         1.0
# 11        11         1.0

# %%
sns.barplot(x='Pclass', y='Fare', hue='Ticket_group_size', data=full_df);

# %%
tickets_not_shared = full_df[full_df['Ticket_group_size']==1]
sns.boxplot(x='Pclass', y='Fare', data=tickets_not_shared);

# %% [markdown]
# **Finding and analyzing the outliers of the fFares:**
# In the section [Overview](#Overview), it's already mentioned that some tickets were complimentary (fare value=0).
# For Pclass 1, one ticket's fare was very low, around 5. For Pclass 1 and Pclass 3, the maximum fares nearly doubles the median. Whether these values are correct, will be further analyzed next.

# %%
#Locate the record of very cheap Pclass1 ticket 
tickets_not_shared[(tickets_not_shared.Pclass==1) & (tickets_not_shared.Fare.isin(range(1,10)))]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 872          873       0.0       1  Carlsson, Mr. Frans Olof  male  33.0
#
#      SibSp  Parch Ticket  Fare        Cabin Embarked  Is_train  \
# 872      0      0    695   5.0  B51 B53 B55        S         1
#
#      Ticket_group_size
# 872                  1

# %% [markdown]
# **Search online about the ticket fare of Mr. Frans:**
# According to [Geni](https://www.geni.com/people/Frans-Olof-Carlsson-1st-Class-RMS-Titanic-Casualty/6000000015948569078), Mr. Frans' ticket fare was indeed  £5.

# %%
#Locate the records of very expensive Pclass1 tickets
tickets_not_shared[(tickets_not_shared.Pclass==1) & (tickets_not_shared.Fare > 50)]
# Out:
#       PassengerId  Survived  Pclass                                  Name  \
# 867           868       0.0       1  Roebling, Mr. Washington Augustus II
# 1057         1058       NaN       1                    Brandeis, Mr. Emil
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Is_train  \
# 867   male  31.0      0      0  PC 17590  50.4958   A24        S         1
# 1057  male  48.0      0      0  PC 17591  50.4958   B10        C         0
#
#       Ticket_group_size
# 867                   1
# 1057                  1

# %% [markdown]
# **Search online about the ticket fare of Mr. Washington:**
# As [Encyclopedia-titanica](https://www.encyclopedia-titanica.org/titanic-victim/washington-roebling.html) mentions, Mr. Washington carried ticket no. PC 17590 (£50 9s 11d). So the fare was confirmed.

# %%
tickets_not_shared[(tickets_not_shared.Pclass==3) & (tickets_not_shared.Fare > 15)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 451          452       0.0       3       Hagland, Mr. Ingvald Olai Olsen
# 490          491       0.0       3  Hagland, Mr. Konrad Mathias Reiersen
#
#       Sex  Age  SibSp  Parch Ticket     Fare Cabin Embarked  Is_train  \
# 451  male  NaN      1      0  65303  19.9667   NaN        S         1
# 490  male  NaN      1      0  65304  19.9667   NaN        S         1
#
#      Ticket_group_size
# 451                  1
# 490                  1

# %% [markdown]
# **Search online about the ticket fares of Mr. Ingvald and Mr. Konrad**
# As [Encyclopedia-titanica ](https://www.encyclopedia-titanica.org/titanic-victim/ingvald-olai-olsen-hagland.html) mentions, Mr. Ingvald was the brother in law of Mr. Konrad and their ticket fares were £6, 19s, 4d, within the normal fare range of Pclass 3. So their fare values in our data are wrong and should be 6.9667.
# <a id="wrong_fares"></a>

# %%
#Correct the two wrong fare values
full_df.loc[[451, 490], 'Fare'] = 6.9667
full_df.iloc[[451, 490]]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 451          452       0.0       3       Hagland, Mr. Ingvald Olai Olsen
# 490          491       0.0       3  Hagland, Mr. Konrad Mathias Reiersen
#
#       Sex  Age  SibSp  Parch Ticket    Fare Cabin Embarked  Is_train  \
# 451  male  NaN      1      0  65303  6.9667   NaN        S         1
# 490  male  NaN      1      0  65304  6.9667   NaN        S         1
#
#      Ticket_group_size
# 451                  1
# 490                  1

# %% [markdown]
# **Finding and analysis on fare-sharing:**
# Almost half of the passengers share the ticket numbers with some other(s). Most of the ticket groups have 2 or 3 persons.The biggest group has 11 people.In each group,their fare values are the same, with only one exception that the two fare values of ticket '7534' are slightly different (9.22, 9.84).
#
# In each of the Pclasses, the fares tend to increase with the ticket group sizes.So it confirms that the members of a ticket group share the ticket fare. Among the passengers who did not share the ticket numbers, their fare ranges of different Pclasses rarely overlap.
# Due to the high percentages of fare sharing, the direct comparison of the fare values among different samples can be misleading.
#
# However, we don't know how they split the fare for the share may vary with the individual's travelling distance and the age. It will be further analyzed next.

# %%
#Look for different embarked values within each ticket-sharing group
are_embarked_different  = full_df.groupby('Ticket').Embarked.nunique() >1
are_embarked_different[are_embarked_different].index.tolist()
# Out:
# ['113798', 'PC 17760']

# %%
full_df.loc[full_df['Ticket'].isin(['113798', 'PC 17760']), :'Embarked'].sort_values(by='Ticket')
# Out:
#       PassengerId  Survived  Pclass                                   Name  \
# 270           271       0.0       1                  Cairns, Mr. Alexander
# 842           843       1.0       1                Serepeca, Miss. Augusta
# 269           270       1.0       1                 Bissette, Miss. Amelia
# 325           326       1.0       1               Young, Miss. Marie Grice
# 373           374       0.0       1                    Ringhini, Mr. Sante
# 1205         1206       NaN       1  White, Mrs. John Stuart (Ella Holmes)
#
#          Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 270     male   NaN      0      0    113798   31.0000   NaN        S
# 842   female  30.0      0      0    113798   31.0000   NaN        C
# 269   female  35.0      0      0  PC 17760  135.6333   C99        S
# 325   female  36.0      0      0  PC 17760  135.6333   C32        C
# 373     male  22.0      0      0  PC 17760  135.6333   NaN        C
# 1205  female  55.0      0      0  PC 17760  135.6333   C32        C

# %%
sns.boxplot(x='Pclass', hue='Embarked', y='Fare', data=tickets_not_shared);

# %%
tickets_not_shared.groupby(['Pclass', 'Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           29.7000
#         S           26.5500
# 2       C           13.8625
#         Q           12.3500
#         S           13.0000
# 3       C            7.2292
#         Q            7.7500
#         S            7.8958
# Name: Fare, dtype: float64

# %%
tickets_not_shared.groupby(['Pclass', 'Embarked']).Fare.describe()
# Out:
#                  count       mean        std      min       25%      50%  \
# Pclass Embarked
# 1      C          37.0  32.169700   7.152371  25.7417  27.72080  29.7000
#        S          69.0  27.474999  10.246828   0.0000  26.00000  26.5500
# 2      C          15.0  14.100267   1.028013  12.0000  13.82500  13.8625
#        Q           7.0  11.735114   1.090680   9.6875  11.52915  12.3500
#        S         114.0  11.950219   2.355105   0.0000  10.50000  13.0000
# 3      C          57.0   7.250888   0.584346   4.0125   7.22500   7.2292
#        Q          91.0   7.716623   0.244534   6.7500   7.74585   7.7500
#        S         322.0   8.052067   1.171298   3.1708   7.77500   7.8958
#
#                      75%      max
# Pclass Embarked
# 1      C         31.6792  50.4958
#        S         30.5000  50.4958
# 2      C         15.0458  15.5792
#        Q         12.3500  12.3500
#        S         13.0000  16.0000
# 3      C          7.2292   8.7125
#        Q          7.7500   8.4583
#        S          8.0500  19.9667

# %%
full_df[full_df.Fare==4.0125]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 378          379       0.0       3  Betros, Mr. Tannous  male  20.0      0
#
#      Parch Ticket    Fare Cabin Embarked  Is_train  Ticket_group_size
# 378      0   2648  4.0125   NaN        C         1                  1

# %% [markdown]
# **Finding:**
# Except for 2 ticket groups (3 persons each), all the members of each group embarked from the same port.
# The fares does not vary much within each Pclass and the median fare values' differences are around 10%.

# %%
tickets_not_shared_nonull = tickets_not_shared.dropna(subset=['Age', 'Fare'])
pclass_values = tickets_not_shared_nonull.Pclass.tolist()
ax = sns.scatterplot(x='Age', y='Fare', hue=pclass_values, data=tickets_not_shared_nonull, legend='full');
ax.legend(title='Pclass');

# %% [markdown]
# **Finding:**
# As the graph shows, there's no obvious correlation between fare and age within each Pclass.
# However, we can't jump to the conclusion that the fare is the same for all the ages because these analyzed records only involve the ages near 10 or above.
# In our common sense, no fee is charged to the infant.

# %%
cols_infants = ['PassengerId', 'Pclass', 'Name', 'Age', 'SibSp', \
                'Parch', 'Ticket', 'Fare', 'Embarked','Ticket_group_size']
infants_df = full_df[full_df.Age<1]
print(infants_df.Pclass.value_counts())
infants_df.sort_values(by='Pclass')[cols_infants]
# Out:
# 3    7
# 2    4
# 1    1
# Name: Pclass, dtype: int64
#       PassengerId  Pclass                                     Name   Age  \
# 305           306       1           Allison, Master. Hudson Trevor  0.92
# 78             79       2            Caldwell, Master. Alden Gates  0.83
# 755           756       2                Hamalainen, Master. Viljo  0.67
# 831           832       2          Richards, Master. George Sibley  0.83
# 1141         1142       2                    West, Miss. Barbara J  0.92
# 469           470       3            Baclini, Miss. Helene Barbara  0.75
# 644           645       3                   Baclini, Miss. Eugenie  0.75
# 803           804       3          Thomas, Master. Assad Alexander  0.42
# 1092         1093       3  Danbom, Master. Gilbert Sigvard Emanuel  0.33
# 1172         1173       3           Peacock, Master. Alfred Edward  0.75
# 1198         1199       3                Aks, Master. Philip Frank  0.83
# 1245         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  0.17
#
#       SibSp  Parch              Ticket      Fare Embarked  Ticket_group_size
# 305       1      2              113781  151.5500        S                  6
# 78        0      2              248738   29.0000        S                  3
# 755       1      1              250649   14.5000        S                  2
# 831       1      1               29106   18.7500        S                  3
# 1141      1      2          C.A. 34651   27.7500        S                  4
# 469       2      1                2666   19.2583        C                  4
# 644       2      1                2666   19.2583        C                  4
# 803       0      1                2625    8.5167        C                  2
# 1092      0      2              347080   14.4000        S                  3
# 1172      1      1  SOTON/O.Q. 3101315   13.7750        S                  3
# 1198      0      1              392091    9.3500        S                  2
# 1245      1      2           C.A. 2315   20.5750        S                  4

# %%
full_df[full_df.Ticket=='2666']
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 448          449       1.0       3         Baclini, Miss. Marie Catherine
# 469          470       1.0       3          Baclini, Miss. Helene Barbara
# 644          645       1.0       3                 Baclini, Miss. Eugenie
# 858          859       1.0       3  Baclini, Mrs. Solomon (Latifa Qurban)
#
#         Sex    Age  SibSp  Parch Ticket     Fare Cabin Embarked  Is_train  \
# 448  female   5.00      2      1   2666  19.2583   NaN        C         1
# 469  female   0.75      2      1   2666  19.2583   NaN        C         1
# 644  female   0.75      2      1   2666  19.2583   NaN        C         1
# 858  female  24.00      0      3   2666  19.2583   NaN        C         1
#
#      Ticket_group_size
# 448                  4
# 469                  4
# 644                  4
# 858                  4

# %% [markdown]
# **Finding:**
# There were 12 infants on board, 7 of Pclass3, 4 of Pclass 2, 1 of Pclass1.
# '2666' Ticket: Pclass 3, Embarked 'C', fare 19.2598, 4 persons including 2 infants (<1), 1 older child (5), 1 parent

# %%
infant_tickets = infants_df.Ticket.tolist()

# %%
#Compare Fare_mean between the group with infant(s) and without infant

# %%
full_df['Fare_mean'] = full_df['Fare']/full_df['Ticket_group_size']
#sns.boxplot(x='Pclass', y='Fare_mean', data=full_df[full_df['Ticket_group_size']!=1]);

# %%
shared_wo_infants = (full_df.Ticket.isin(shared_tickets)) & (~full_df.Ticket.isin(infant_tickets))  
full_df.loc[shared_wo_infants].groupby(['Pclass', 'Embarked']).Fare_mean.describe()
# Out:
#                  count       mean        std        min        25%        50%  \
# Pclass Embarked
# 1      C         104.0  40.513944  20.856704  15.500000  28.875000  36.891071
#        Q           3.0  30.000000   0.000000  30.000000  30.000000  30.000000
#        S         102.0  32.667036  11.793423   0.000000  26.000000  27.725000
# 2      C          13.0  12.336538   1.696072  10.394800  10.394800  12.334733
#        S         116.0  10.814655   2.689182   0.000000   9.750000  10.666667
# 3      C          38.0   6.582897   1.192830   5.081933   5.247233   7.226750
#        Q          22.0   7.001136   1.349560   4.854167   5.578125   7.750000
#        S         160.0   6.191913   1.669245   0.000000   5.093340   6.322727
#
#                        75%        max
# Pclass Embarked
# 1      C         41.389050  128.08230
#        Q         30.000000   30.00000
#        S         41.216675   66.82500
# 2      C         13.860400   15.03540
#        S         13.000000   15.00000
# 3      C          7.227100    9.39375
#        Q          7.750000    8.05000
#        S          7.272917    9.00000

# %%
full_df.loc[full_df.Ticket.isin(infant_tickets)].groupby(['Pclass', 'Embarked']).Fare_mean.describe()
# Out:
#                  count       mean       std        min        25%        50%  \
# Pclass Embarked
# 1      S           6.0  25.258333  0.000000  25.258333  25.258333  25.258333
# 2      S          12.0   7.500000  1.353832   6.250000   6.765625   6.937500
# 3      C           6.0   4.629167  0.287233   4.258350   4.397406   4.814575
#        S          12.0   4.841667  0.236120   4.591667   4.654167   4.800000
#
#                        75%        max
# Pclass Embarked
# 1      S         25.258333  25.258333
# 2      S          7.854167   9.666667
# 3      C          4.814575   4.814575
#        S          5.143750   5.143750

# %% [markdown]
# **Finding and analysis of categorical variables and fare-sharing:**
# The number of the survivors is only half of that of the victims. So this is an imbalanced classfication task.
# The istributions of 'Pclass', 'Sex', 'Embarked' are also imbalanced.
#
# 'Cabin' and 'Ticket' have several hundreds of categories. Many of them only appear in one sample record.Some cabins accomodated more than one passengers. It makes sense. However, it's a bit suprising that some passengers are sharing the same 'Ticket' number and the same Fare. Of the 60 records I checked, according to the names and [encyclopedia-titanic](https://www.encyclopedia-titanica.org/), the ticket-sharing passengers may be somehow related (family members, employer & maid & valet, colleagues).The fare values of their records is the total value of all of them. So their fare values are much higher than the others.

# %% [markdown]
# ### Check the relationship between Survived and other variables

# %% [markdown]
# #### Check how survival rates vary with the numerical variables

# %%
#Compare the variation of variable values (median) by Survived
pd.pivot_table(full_df, index='Survived', values=cols_num, aggfunc=np.median)
# Out:
#            Age  Fare  Parch  SibSp
# Survived
# 0.0       28.0  10.5      0      0
# 1.0       28.0  26.0      0      0

# %%
pd.pivot_table(full_df[full_df.Ticket_group_size==1], index='Survived', \
               values=['Fare'], aggfunc=np.median)
# Out:
#             Fare
# Survived
# 0.0        7.925
# 1.0       10.500

# %% [markdown]
# **Finding:**
# The median values of these numerical variables do not vary by Survived, except for Fare.

# %%
compare_hists('Age', bins=np.arange(0, 90, 5))

# %% [markdown]
# **Finding:**
# The group of age below 5 has much higher survival rates than the rest.
# Above 65, there are barely any survivors.

# %%
#As analyzed earlier, half of the passengers shared the fares with some other(s)
#So only the non-sharing records are selected for the comparison
compare_hists('Fare', bins=range(0, 60, 5),df=full_df[full_df.Ticket_group_size==1])

# %% [markdown]
# **Finding:**
# The survival rates at fares above 20 are much higher.

# %%
stack_bar('Parch')

# %% [markdown]
# **Finding:**
# The survival rates at Parch values f 1 and 2 are much higher than that at Parch value 0.

# %%
stack_bar('SibSp')

# %% [markdown]
# **Finding:**
# The survival rate at SibSp value of 1 is much higher than that at SibSp value 0.

# %% [markdown]
# #### Check how survival rates vary with the categorical variables

# %%
#Check the categorical variables with only a few unique values
for col in cols_few_cat[1:]:
    table = pd.pivot_table(full_df, index='Survived', columns=col, values='PassengerId', aggfunc='count', margins=True)
    #print('Count:')
    #print(table)
    #print('')
    print('Survival rates (%) varied by {}:'.format(col))
    display(round(100*table.iloc[[1], :-1].div(table.iloc[-1, :-1], axis=1)))
    print('')
# Out:
# Survival rates (%) varied by Pclass:
# Pclass       1     2     3
# Survived
# 1.0       63.0  47.0  24.0
# Survival rates (%) varied by Sex:
# Sex       female  male
# Survived
# 1.0         74.0  19.0
# Survival rates (%) varied by Embarked:
# Embarked     C     Q     S
# Survived
# 1.0       55.0  39.0  34.0

# %%
stack_bar('Pclass')

# %%
stack_bar('Sex')

# %%
stack_bar('Embarked')

# %% [markdown]
# **Finding:**
# Pclass is related with the survival rate. Pclass 1 > Pclass 2 > Pclass 3.
# Sex is very much related with the survival rate. The female' survival rate is more than 3 times as high survial rate as the male.
# As for Embarked, the survival rate of Q is much higher than S and C.

# %% [markdown]
# #### Correlation between variables
# According to [Pearson Product-Moment Correlation](https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide-2.php) and [Spearman's Rank-Order Correlation](https://statistics.laerd.com/statistical-guides/spearmans-rank-order-correlation-statistical-guide-2.php) from Laerd website:
# Pearson Product-Moment Correlation is between two interval or ratio variables which are normally distributed.As all variables but 'Age' fail to meet this requirement, this method is not appliable.
# Instead, Spearman Rank-Order Correlation method is applicable here for it only requires the variables to be either ordinal, interval or ratio. This method measures the strength and direction of the monotonic relationship between two ranked variables.

# %%
#map the sex values to 0 and 1, and create a new column 'Is_female'
full_df['Is_female'] = full_df['Sex'].map({'female': 1, 'male': 0})
full_df.drop('Sex',axis=1,inplace=True)
features = ['Survived', 'Pclass', 'Is_female', 'Age', 'SibSp', 'Parch', 'Fare']
corr_spearman = full_df[features].corr(method='spearman')['Survived']
corr_spearman
# Out:
# Survived     1.000000
# Pclass      -0.339668
# Is_female    0.543351
# Age         -0.051146
# SibSp        0.084307
# Parch        0.135611
# Fare         0.326285
# Name: Survived, dtype: float64

# %%
#use heatmap for visualization and choose contrast colors for a more clear view
display(round(full_df[features].corr(method='spearman'), 2))
sns.heatmap(full_df[features].corr(method='spearman'), cmap="PiYG");
# Out:
#            Survived  Pclass  Is_female   Age  SibSp  Parch  Fare
# Survived       1.00   -0.34       0.54 -0.05   0.08   0.14  0.33
# Pclass        -0.34    1.00      -0.12 -0.39  -0.07  -0.03 -0.71
# Is_female      0.54   -0.12       1.00 -0.06   0.17   0.24  0.24
# Age           -0.05   -0.39      -0.06  1.00  -0.14  -0.21  0.19
# SibSp          0.08   -0.07       0.17 -0.14   1.00   0.43  0.45
# Parch          0.14   -0.03       0.24 -0.21   0.43   1.00  0.41
# Fare           0.33   -0.71       0.24  0.19   0.45   0.41  1.00

# %%
#check the correlation between Fare and Pclass after removing the records containing the shared ticket numbers
round(tickets_not_shared[['Fare', 'Pclass']].corr(method='spearman').iloc[0,1], 2)
# Out:
# -0.77

# %% [markdown]
# **Finding and analysis**
# The top 3 most related variables for Survived: Is_female (0.54), Pclass (-0.33), Fare (0.32).
# Among these three, Pclass and Fare are highly correlated (-0.69).Excluding the records containing the shared ticket values, their correlation got stronger (-0.77).
# Among all the variables, Age has the most weak correlation with Survived (-0.05), indicating very weak monotonic relationship.This doesn't necessarily mean that there's no relationship between 'Age' and 'Survived'. The above analysis shows that the children have a much higher survival rates and the elderly have a much a lower survival rates.

# %% [markdown]
# ### Further analysis of 'Cabin' and 'Ticket'

# %%
#check the unique values of Cabin column
full_df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
#        'E58', 'C126', 'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'F G63',
#        'C62 C64', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30',
#        'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'B82 B84', 'D17', 'A36',
#        'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42',
#        'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C55 C57', 'C116', 'F', 'A29', 'C6', 'C28',
#        'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80',
#        'C89', 'F E46', 'B26', 'F E57', 'A18', 'E60', 'E39 E41',
#        'B52 B54 B56', 'C39', 'B24', 'D40', 'D38', 'C105'], dtype=object)

# %%
round(full_df.loc[pd.notnull(full_df.Cabin), 'Survived'].mean(),2)
# Out:
# 0.67

# %%
unique_cabin_values = full_df.Cabin.dropna().unique()
digit_only_values = []
alpha_only_values = []
long_values = [] #the cabin values of which the length is more than 4
other_values = []
for v in unique_cabin_values:
    if v.isdigit():
        digit_only_values.append(v)
    elif v.isalpha():
        alpha_only_values.append(v)
    elif len(v)>4:
        long_values.append(v)
    else:
        other_values.append(v)

# %%
print('Different formats of Cabin values were found:\n')
print('Alpha-only values: {}\n'.format(alpha_only_values))
print('Long values: {}\n'.format(long_values))
print('Other values: {}\n'.format(other_values))
# Out:
# Different formats of Cabin values were found:
#
# Alpha-only values: ['D', 'T', 'F']
#
# Long values: ['C23 C25 C27', 'F G73', 'D10 D12', 'B58 B60', 'F E69', 'C22 C26', 'B57 B59 B63 B66', 'B96 B98', 'B51 B53 B55', 'F G63', 'C62 C64', 'B82 B84', 'C55 C57', 'F E46', 'F E57', 'E39 E41', 'B52 B54 B56']
#
# Other values: ['C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33', 'E31', 'A5', 'D26', 'C110', 'E101', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19', 'B49', 'C106', 'C65', 'E36', 'C54', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'C128', 'D37', 'B35', 'E50', 'C82', 'E10', 'E44', 'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126', 'B71', 'D49', 'B5', 'B20', 'E24', 'C90', 'C45', 'E8', 'B101', 'D45', 'C46', 'D30', 'E121', 'D11', 'E77', 'F38', 'B3', 'D6', 'D17', 'A36', 'B102', 'B69', 'E49', 'C47', 'D28', 'E17', 'A24', 'C50', 'B42', 'C148', 'B45', 'B36', 'A21', 'D34', 'A9', 'C31', 'B61', 'C53', 'D43', 'C130', 'C132', 'C116', 'A29', 'C6', 'C28', 'C51', 'C97', 'D22', 'B10', 'E45', 'E52', 'A11', 'B11', 'C80', 'C89', 'B26', 'A18', 'E60', 'C39', 'B24', 'D40', 'D38', 'C105']

# %%
display(full_df[full_df.Cabin.isin(['B61', 'B57 B59 B63 B66'])])
# Out:
#       PassengerId  Survived  Pclass  \
# 311           312       1.0       1
# 742           743       1.0       1
# 915           916       NaN       1
# 950           951       NaN       1
# 955           956       NaN       1
# 1033         1034       NaN       1
#
#                                                  Name   Age  SibSp  Parch  \
# 311                        Ryerson, Miss. Emily Borie  18.0      2      2
# 742             Ryerson, Miss. Susan Parker "Suzette"  21.0      2      2
# 915   Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  48.0      1      3
# 950                       Chaudanson, Miss. Victorine  36.0      0      0
# 955                       Ryerson, Master. John Borie  13.0      2      2
# 1033                       Ryerson, Mr. Arthur Larned  61.0      1      3
#
#         Ticket     Fare            Cabin Embarked  Is_train  \
# 311   PC 17608  262.375  B57 B59 B63 B66        C         1
# 742   PC 17608  262.375  B57 B59 B63 B66        C         1
# 915   PC 17608  262.375  B57 B59 B63 B66        C         0
# 950   PC 17608  262.375              B61        C         0
# 955   PC 17608  262.375  B57 B59 B63 B66        C         0
# 1033  PC 17608  262.375  B57 B59 B63 B66        C         0
#
#       Ticket_group_size  Fare_mean  Is_female
# 311                   7  37.482143          1
# 742                   7  37.482143          1
# 915                   7  37.482143          1
# 950                   7  37.482143          1
# 955                   7  37.482143          0
# 1033                  7  37.482143          0

# %%
full_df.loc[(full_df.Ticket_group_size==1) & (full_df.Pclass==1), 'Fare'].hist()
# Out:
# <AxesSubplot:>

# %%
other_values.sort()
other_values
# Out:
# ['A10',
#  'A11',
#  'A14',
#  'A16',
#  'A18',
#  'A19',
#  'A20',
#  'A21',
#  'A23',
#  'A24',
#  'A26',
#  'A29',
#  'A31',
#  'A32',
#  'A34',
#  'A36',
#  'A5',
#  'A6',
#  'A7',
#  'A9',
#  'B10',
#  'B101',
#  'B102',
#  'B11',
#  'B18',
#  'B19',
#  'B20',
#  'B22',
#  'B24',
#  'B26',
#  'B28',
#  'B3',
#  'B30',
#  'B35',
#  'B36',
#  'B37',
#  'B38',
#  'B39',
#  'B4',
#  'B41',
#  'B42',
#  'B45',
#  'B49',
#  'B5',
#  'B50',
#  'B61',
#  'B69',
#  'B71',
#  'B73',
#  'B77',
#  'B78',
#  'B79',
#  'B80',
#  'B86',
#  'B94',
#  'C101',
#  'C103',
#  'C104',
#  'C105',
#  'C106',
#  'C110',
#  'C111',
#  'C116',
#  'C118',
#  'C123',
#  'C124',
#  'C125',
#  'C126',
#  'C128',
#  'C130',
#  'C132',
#  'C148',
#  'C2',
#  'C28',
#  'C30',
#  'C31',
#  'C32',
#  'C39',
#  'C45',
#  'C46',
#  'C47',
#  'C49',
#  'C50',
#  'C51',
#  'C52',
#  'C53',
#  'C54',
#  'C6',
#  'C65',
#  'C68',
#  'C7',
#  'C70',
#  'C78',
#  'C80',
#  'C82',
#  'C83',
#  'C85',
#  'C86',
#  'C87',
#  'C89',
#  'C90',
#  'C91',
#  'C92',
#  'C93',
#  'C95',
#  'C97',
#  'C99',
#  'D11',
#  'D15',
#  'D17',
#  'D19',
#  'D20',
#  'D21',
#  'D22',
#  'D26',
#  'D28',
#  'D30',
#  'D33',
#  'D34',
#  'D35',
#  'D36',
#  'D37',
#  'D38',
#  'D40',
#  'D43',
#  'D45',
#  'D46',
#  'D47',
#  'D48',
#  'D49',
#  'D50',
#  'D56',
#  'D6',
#  'D7',
#  'D9',
#  'E10',
#  'E101',
#  'E12',
#  'E121',
#  'E17',
#  'E24',
#  'E25',
#  'E31',
#  'E33',
#  'E34',
#  'E36',
#  'E38',
#  'E40',
#  'E44',
#  'E45',
#  'E46',
#  'E49',
#  'E50',
#  'E52',
#  'E58',
#  'E60',
#  'E63',
#  'E67',
#  'E68',
#  'E77',
#  'E8',
#  'F2',
#  'F33',
#  'F38',
#  'F4',
#  'G6']

# %%
full_df['Cabin_quantity'] = 1
four_cabins = ['B57 B59 B63 B66']
three_cabins = ['C23 C25 C27', 'B51 B53 B55', 'B52 B54 B56']
two_cabins = ['D10 D12', 'B58 B60', 'C22 C26', 'B96 B98', 'C62 C64', 'B82 B84', 'C55 C57', 'E39 E41']
full_df.loc[full_df.Cabin.isin(four_cabins), 'Cabin_quantity']=4
full_df.loc[full_df.Cabin.isin(three_cabins), 'Cabin_quantity']=3
full_df.loc[full_df.Cabin.isin(two_cabins), 'Cabin_quantity']=2

# %%
full_df[full_df.Cabin_quantity>1].sort_values(by='Ticket')
# Out:
#       PassengerId  Survived  Pclass  \
# 1263         1264       NaN       1
# 802           803       1.0       1
# 435           436       1.0       1
# 390           391       1.0       1
# 763           764       1.0       1
# 305           306       1.0       1
# 1197         1198       NaN       1
# 498           499       0.0       1
# 297           298       0.0       1
# 1262         1263       NaN       1
# 27             28       0.0       1
# 341           342       1.0       1
# 960           961       NaN       1
# 944           945       NaN       1
# 438           439       0.0       1
# 88             89       1.0       1
# 872           873       0.0       1
# 1005         1006       NaN       1
# 972           973       NaN       1
# 1075         1076       NaN       1
# 118           119       0.0       1
# 299           300       1.0       1
# 789           790       0.0       1
# 955           956       NaN       1
# 915           916       NaN       1
# 742           743       1.0       1
# 1033         1034       NaN       1
# 311           312       1.0       1
# 679           680       1.0       1
# 1234         1235       NaN       1
# 700           701       1.0       1
# 1093         1094       NaN       1
# 1241         1242       NaN       1
# 97             98       1.0       1
#
#                                                    Name    Age  SibSp  Parch  \
# 1263                            Ismay, Mr. Joseph Bruce  49.00      0      0
# 802                 Carter, Master. William Thornton II  11.00      1      2
# 435                           Carter, Miss. Lucile Polk  14.00      1      2
# 390                          Carter, Mr. William Ernest  36.00      1      2
# 763           Carter, Mrs. William Ernest (Lucile Polk)  36.00      1      2
# 305                      Allison, Master. Hudson Trevor   0.92      1      2
# 1197               Allison, Mr. Hudson Joshua Creighton  30.00      1      2
# 498     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00      1      2
# 297                        Allison, Miss. Helen Loraine   2.00      1      2
# 1262                          Wilson, Miss. Helen Alice  31.00      0      0
# 27                       Fortune, Mr. Charles Alexander  19.00      3      2
# 341                      Fortune, Miss. Alice Elizabeth  24.00      3      2
# 960                 Fortune, Mrs. Mark (Mary McDougald)  60.00      1      4
# 944                          Fortune, Miss. Ethel Flora  28.00      3      2
# 438                                   Fortune, Mr. Mark  64.00      1      4
# 88                           Fortune, Miss. Mabel Helen  23.00      3      2
# 872                            Carlsson, Mr. Frans Olof  33.00      0      0
# 1005             Straus, Mrs. Isidor (Rosalie Ida Blun)  63.00      1      0
# 972                                  Straus, Mr. Isidor  67.00      1      0
# 1075  Douglas, Mrs. Frederick Charles (Mary Helene B...  27.00      1      1
# 118                            Baxter, Mr. Quigg Edmond  24.00      0      1
# 299     Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.00      0      1
# 789                            Guggenheim, Mr. Benjamin  46.00      0      0
# 955                         Ryerson, Master. John Borie  13.00      2      2
# 915     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  48.00      1      3
# 742               Ryerson, Miss. Susan Parker "Suzette"  21.00      2      2
# 1033                         Ryerson, Mr. Arthur Larned  61.00      1      3
# 311                          Ryerson, Miss. Emily Borie  18.00      2      2
# 679                  Cardeza, Mr. Thomas Drake Martinez  36.00      0      1
# 1234  Cardeza, Mrs. James Warburton Martinez (Charlo...  58.00      0      1
# 700   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.00      1      0
# 1093                             Astor, Col. John Jacob  47.00      1      0
# 1241       Greenfield, Mrs. Leo David (Blanche Strouse)  45.00      0      1
# 97                      Greenfield, Mr. William Bertram  23.00      0      1
#
#         Ticket      Fare            Cabin Embarked  Is_train  \
# 1263    112058    0.0000      B52 B54 B56        S         0
# 802     113760  120.0000          B96 B98        S         1
# 435     113760  120.0000          B96 B98        S         1
# 390     113760  120.0000          B96 B98        S         1
# 763     113760  120.0000          B96 B98        S         1
# 305     113781  151.5500          C22 C26        S         1
# 1197    113781  151.5500          C22 C26        S         0
# 498     113781  151.5500          C22 C26        S         1
# 297     113781  151.5500          C22 C26        S         1
# 1262     16966  134.5000          E39 E41        C         0
# 27       19950  263.0000      C23 C25 C27        S         1
# 341      19950  263.0000      C23 C25 C27        S         1
# 960      19950  263.0000      C23 C25 C27        S         0
# 944      19950  263.0000      C23 C25 C27        S         0
# 438      19950  263.0000      C23 C25 C27        S         1
# 88       19950  263.0000      C23 C25 C27        S         1
# 872        695    5.0000      B51 B53 B55        S         1
# 1005  PC 17483  221.7792          C55 C57        S         0
# 972   PC 17483  221.7792          C55 C57        S         0
# 1075  PC 17558  247.5208          B58 B60        C         0
# 118   PC 17558  247.5208          B58 B60        C         1
# 299   PC 17558  247.5208          B58 B60        C         1
# 789   PC 17593   79.2000          B82 B84        C         1
# 955   PC 17608  262.3750  B57 B59 B63 B66        C         0
# 915   PC 17608  262.3750  B57 B59 B63 B66        C         0
# 742   PC 17608  262.3750  B57 B59 B63 B66        C         1
# 1033  PC 17608  262.3750  B57 B59 B63 B66        C         0
# 311   PC 17608  262.3750  B57 B59 B63 B66        C         1
# 679   PC 17755  512.3292      B51 B53 B55        C         1
# 1234  PC 17755  512.3292      B51 B53 B55        C         0
# 700   PC 17757  227.5250          C62 C64        C         1
# 1093  PC 17757  227.5250          C62 C64        C         0
# 1241  PC 17759   63.3583          D10 D12        C         0
# 97    PC 17759   63.3583          D10 D12        C         1
#
#       Ticket_group_size   Fare_mean  Is_female  Cabin_quantity
# 1263                  2    0.000000          0               3
# 802                   4   30.000000          0               2
# 435                   4   30.000000          1               2
# 390                   4   30.000000          0               2
# 763                   4   30.000000          1               2
# 305                   6   25.258333          0               2
# 1197                  6   25.258333          0               2
# 498                   6   25.258333          1               2
# 297                   6   25.258333          1               2
# 1262                  5   26.900000          1               2
# 27                    6   43.833333          0               3
# 341                   6   43.833333          1               3
# 960                   6   43.833333          1               3
# 944                   6   43.833333          1               3
# 438                   6   43.833333          0               3
# 88                    6   43.833333          1               3
# 872                   1    5.000000          0               3
# 1005                  4   55.444800          1               2
# 972                   4   55.444800          0               2
# 1075                  3   82.506933          1               2
# 118                   3   82.506933          0               2
# 299                   3   82.506933          1               2
# 789                   2   39.600000          0               2
# 955                   7   37.482143          0               4
# 915                   7   37.482143          1               4
# 742                   7   37.482143          1               4
# 1033                  7   37.482143          0               4
# 311                   7   37.482143          1               4
# 679                   4  128.082300          0               3
# 1234                  4  128.082300          1               3
# 700                   5   45.505000          1               2
# 1093                  5   45.505000          0               2
# 1241                  2   31.679150          1               2
# 97                    2   31.679150          0               2

# %% [markdown]
# **Finding and analysis of Cabin**
# 1. Four formats of Cabin values
# All the 'Cabin' values start with a letter.
# Of the majority of uniuqe values, the letter is followed by a 1~3 digits.
# Of a few uniuqe Cabin values, they consist of the values of several single cabins.
# Of several uniuqe values, they consist of a letter and a cabin value.
# Only two unique values include nothing but a letter.
#
# 2. Letter indicates deck
# The letter of 'Cabin' value is the indication for deck.
# According to the [deck plan](http://ssmaritime.com/Titanic-3.htm), ‘Boat Deck’ was the uppermost deck on the Titanic.Deck A was just below Boat Deck, Deck B below Deck C, Deck D below Deck D...
# According to [the encyclopedia](https://www.encyclopedia-titanica.org/titanic-deckplans/), ‘F G73', 'F E69' cabinets were on Deck F. 'D' on Deck D, 'T' on Boat Deck.
# 3. A suite made from djacent cabins
# 'C23 C25 C27', 'D10 D12', 'B58 B60', 'C22 C26', 'B57 B59 B63 B66', 'B96 B98', 'B51 B53 B55', 'C62 C64', 'B82 B84', these cabinet values are of two or three adjacent cabins. According to [ultimatetitanic]( https://www.ultimatetitanic.com/interior-fittings), 'If a parlor suite didn't suffice, a wealthy family could purchase several first-class cabins adjacent to one another and open the interconnecting doors between the cabins to have a suite of their own'.
# 4. Large percentage of missingness greatly compromising Cabin's vadility
# The survival rate is 0.67 for the samples with given Cabin values. This is inconsistent with the overal survival rate (38%）. So the missingness of 'Cabin' values is related with 'Survived'. Due to the large proportion (77%) of missing values and its relation to the outcome 'Survived', the data distribution of 'Cabin' is no longer representative of the whole population. So We need to be very cautious with its usage.

# %% [markdown]
# 2. Ticket
# Two forms of 'Ticket' values: alpha_only, the rest(including alpha, digit, some symbols.

# %%
#check the unique values of Ticket column
full_df.Ticket.unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
#        '248738', '364516', '345767', '345779', '330932', '113059',
#        'SO/C 14885', '3101278', 'W./C. 6608', 'SOTON/OQ 392086', '343275',
#        '343276', '347466', 'W.E.P. 5734', 'C.A. 2315', '364500', '374910',
#        'PC 17754', 'PC 17759', '231919', '244367', '349245', '349215',
#        '35281', '7540', '3101276', '349207', '343120', '312991', '349249',
#        '371110', '110465', '2665', '324669', '4136', '2627',
#        'STON/O 2. 3101294', '370369', 'PC 17558', 'A4. 54510', '27267',
#        '370372', 'C 17369', '2668', '347061', '349241',
#        'SOTON/O.Q. 3101307', 'A/5. 3337', '228414', 'C.A. 29178',
#        'SC/PARIS 2133', '11752', '7534', 'PC 17593', '2678', '347081',
#        'STON/O2. 3101279', '365222', '231945', 'C.A. 33112', '350043',
#        '230080', '244310', 'S.O.P. 1166', '113776', 'A.5. 11206',
#        'A/5. 851', 'Fa 265302', 'PC 17597', '35851', 'SOTON/OQ 392090',
#        '315037', 'CA. 2343', '371362', 'C.A. 33595', '347068', '315093',
#        '363291', '113505', 'PC 17318', '111240', 'STON/O 2. 3101280',
#        '17764', '350404', '4133', 'PC 17595', '250653', 'LINE',
#        'SC/PARIS 2131', '230136', '315153', '113767', '370365', '111428',
#        '364849', '349247', '234604', '28424', '350046', 'PC 17610',
#        '368703', '4579', '370370', '248747', '345770', '3101264', '2628',
#        'A/5 3540', '347054', '2699', '367231', '112277',
#        'SOTON/O.Q. 3101311', 'F.C.C. 13528', 'A/5 21174', '250646',
#        '367229', '35273', 'STON/O2. 3101283', '243847', '11813',
#        'W/C 14208', 'SOTON/OQ 392089', '220367', '21440', '349234',
#        '19943', 'PP 4348', 'SW/PP 751', 'A/5 21173', '236171', '347067',
#        '237442', 'C.A. 29566', 'W./C. 6609', '26707', 'C.A. 31921',
#        '28665', 'SCO/W 1585', '367230', 'W./C. 14263',
#        'STON/O 2. 3101275', '2694', '19928', '347071', '250649', '11751',
#        '244252', '362316', '113514', 'A/5. 3336', '370129', '2650',
#        'PC 17585', '110152', 'PC 17755', '230433', '384461', '110413',
#        '112059', '382649', 'C.A. 17248', '347083', 'PC 17582', 'PC 17760',
#        '113798', '250644', 'PC 17596', '370375', '13502', '347073',
#        '239853', 'C.A. 2673', '336439', '347464', '345778', 'A/5. 10482',
#        '113056', '349239', '345774', '349206', '237798', '370373',
#        '19877', '11967', 'SC/Paris 2163', '349236', '349233', 'PC 17612',
#        '2693', '113781', '19988', '9234', '367226', '226593', 'A/5 2466',
#        '17421', 'PC 17758', 'P/PP 3381', 'PC 17485', '11767', 'PC 17608',
#        '250651', '349243', 'F.C.C. 13529', '347470', '29011', '36928',
#        '16966', 'A/5 21172', '349219', '234818', '345364', '28551',
#        '111361', '113043', 'PC 17611', '349225', '7598', '113784',
#        '248740', '244361', '229236', '248733', '31418', '386525',
#        'C.A. 37671', '315088', '7267', '113510', '2695', '2647', '345783',
#        '237671', '330931', '330980', 'SC/PARIS 2167', '2691',
#        'SOTON/O.Q. 3101310', 'C 7076', '110813', '2626', '14313',
#        'PC 17477', '11765', '3101267', '323951', 'C 7077', '113503',
#        '2648', '347069', 'PC 17757', '2653', 'STON/O 2. 3101293',
#        '349227', '27849', '367655', 'SC 1748', '113760', '350034',
#        '3101277', '350052', '350407', '28403', '244278', '240929',
#        'STON/O 2. 3101289', '341826', '4137', '315096', '28664', '347064',
#        '29106', '312992', '349222', '394140', 'STON/O 2. 3101269',
#        '343095', '28220', '250652', '28228', '345773', '349254',
#        'A/5. 13032', '315082', '347080', 'A/4. 34244', '2003', '250655',
#        '364851', 'SOTON/O.Q. 392078', '110564', '376564', 'SC/AH 3085',
#        'STON/O 2. 3101274', '13507', 'C.A. 18723', '345769', '347076',
#        '230434', '65306', '33638', '113794', '2666', '113786', '65303',
#        '113051', '17453', 'A/5 2817', '349240', '13509', '17464',
#        'F.C.C. 13531', '371060', '19952', '364506', '111320', '234360',
#        'A/S 2816', 'SOTON/O.Q. 3101306', '113792', '36209', '323592',
#        '315089', 'SC/AH Basle 541', '7553', '31027', '3460', '350060',
#        '3101298', '239854', 'A/5 3594', '4134', '11771', 'A.5. 18509',
#        '65304', 'SOTON/OQ 3101317', '113787', 'PC 17609', 'A/4 45380',
#        '36947', 'C.A. 6212', '350035', '315086', '364846', '330909',
#        '4135', '26360', '111427', 'C 4001', '382651', 'SOTON/OQ 3101316',
#        'PC 17473', 'PC 17603', '349209', '36967', 'C.A. 34260', '226875',
#        '349242', '12749', '349252', '2624', '2700', '367232',
#        'W./C. 14258', 'PC 17483', '3101296', '29104', '2641', '2690',
#        '315084', '113050', 'PC 17761', '364498', '13568', 'WE/P 5735',
#        '2908', '693', 'SC/PARIS 2146', '244358', '330979', '2620',
#        '347085', '113807', '11755', '345572', '372622', '349251',
#        '218629', 'SOTON/OQ 392082', 'SOTON/O.Q. 392087', 'A/4 48871',
#        '349205', '2686', '350417', 'S.W./PP 752', '11769', 'PC 17474',
#        '14312', 'A/4. 20589', '358585', '243880', '2689',
#        'STON/O 2. 3101286', '237789', '13049', '3411', '237565', '13567',
#        '14973', 'A./5. 3235', 'STON/O 2. 3101273', 'A/5 3902', '364848',
#        'SC/AH 29037', '248727', '2664', '349214', '113796', '364511',
#        '111426', '349910', '349246', '113804', 'SOTON/O.Q. 3101305',
#        '370377', '364512', '220845', '31028', '2659', '11753', '350029',
#        '54636', '36963', '219533', '349224', '334912', '27042', '347743',
#        '13214', '112052', '237668', 'STON/O 2. 3101292', '350050',
#        '349231', '13213', 'S.O./P.P. 751', 'CA. 2314', '349221', '8475',
#        '330919', '365226', '349223', '29751', '2623', '5727', '349210',
#        'STON/O 2. 3101285', '234686', '312993', 'A/5 3536', '19996',
#        '29750', 'F.C. 12750', 'C.A. 24580', '244270', '239856', '349912',
#        '342826', '4138', '330935', '6563', '349228', '350036', '24160',
#        '17474', '349256', '2672', '113800', '248731', '363592', '35852',
#        '348121', 'PC 17475', '36864', '350025', '223596', 'PC 17476',
#        'PC 17482', '113028', '7545', '250647', '348124', '34218', '36568',
#        '347062', '350048', '12233', '250643', '113806', '315094', '36866',
#        '236853', 'STON/O2. 3101271', '239855', '28425', '233639',
#        '349201', '349218', '16988', '376566', 'STON/O 2. 3101288',
#        '250648', '113773', '335097', '29103', '392096', '345780',
#        '349204', '350042', '29108', '363294', 'SOTON/O2 3101272', '2663',
#        '347074', '112379', '364850', '8471', '345781', '350047',
#        'S.O./P.P. 3', '2674', '29105', '347078', '383121', '36865',
#        '2687', '113501', 'W./C. 6607', 'SOTON/O.Q. 3101312', '374887',
#        '3101265', '12460', 'PC 17600', '349203', '28213', '17465',
#        '349244', '2685', '2625', '347089', '347063', '112050', '347087',
#        '248723', '3474', '28206', '364499', '112058', 'STON/O2. 3101290',
#        'S.C./PARIS 2079', 'C 7075', '315098', '19972', '368323', '367228',
#        '2671', '347468', '2223', 'PC 17756', '315097', '392092', '11774',
#        'SOTON/O2 3101287', '2683', '315090', 'C.A. 5547', '349213',
#        '347060', 'PC 17592', '392091', '113055', '2629', '350026',
#        '28134', '17466', '233866', '236852', 'SC/PARIS 2149', 'PC 17590',
#        '345777', '349248', '695', '345765', '2667', '349212', '349217',
#        '349257', '7552', 'C.A./SOTON 34068', 'SOTON/OQ 392076', '211536',
#        '112053', '111369', '370376', '330911', '363272', '240276',
#        '315154', '7538', '330972', '2657', '349220', '694', '21228',
#        '24065', '233734', '2692', 'STON/O2. 3101270', '2696', 'C 17368',
#        'PC 17598', '2698', '113054', 'C.A. 31029', '13236', '2682',
#        '342712', '315087', '345768', '113778', 'SOTON/O.Q. 3101263',
#        '237249', 'STON/O 2. 3101291', 'PC 17594', '370374', '13695',
#        'SC/PARIS 2168', 'SC/A.3 2861', '349230', '348122', '349232',
#        '237216', '347090', '334914', 'F.C.C. 13534', '330963', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '359306', '11770',
#        '248744', '368702', '19924', '349238', '240261', '2660', '330844',
#        'A/4 31416', '364856', '347072', '345498', '376563', '13905',
#        '350033', 'STON/O 2. 3101268', '347471', 'A./5. 3338', '11778',
#        '365235', '347070', '330920', '383162', '3410', '248734', '237734',
#        '330968', 'PC 17531', '329944', '2681', '13050', '367227',
#        '392095', '368783', '350045', '211535', '342441',
#        'STON/OQ. 369943', '113780', '2621', '349226', '350409', '2656',
#        '248659', 'SOTON/OQ 392083', '17475', 'SC/A4 23568', '113791',
#        '349255', '3701', '350405', 'S.O./P.P. 752', '347469', '110489',
#        'SOTON/O.Q. 3101315', '335432', '220844', '343271', '237393',
#        'PC 17591', '17770', '7548', 'S.O./P.P. 251', '2670', '2673',
#        '233478', '7935', '239059', 'S.O./P.P. 2', 'A/4 48873', '28221',
#        '111163', '235509', '347465', '347066', 'C.A. 31030', '65305',
#        'C.A. 34050', 'F.C. 12998', '9232', '28034', 'PC 17613', '349250',
#        'SOTON/O.Q. 3101308', '347091', '113038', '330924', '32302',
#        'SC/PARIS 2148', '342684', 'W./C. 14266', '350053', 'PC 17606',
#        '350054', '370368', '242963', '113795', '3101266', '330971',
#        '350416', '2679', '250650', '112377', '3470', 'SOTON/O2 3101284',
#        '13508', '7266', '345775', 'C.A. 42795', 'AQ/4 3130', '363611',
#        '28404', '345501', '350410', 'C.A. 34644', '349235', '112051',
#        'C.A. 49867', 'A. 2. 39186', '315095', '368573', '2676',
#        'SC 14888', 'CA 31352', 'W./C. 14260', '315085', '364859',
#        'A/5 21175', 'SOTON/O.Q. 3101314', '2655', 'A/5 1478', 'PC 17607',
#        '382650', '2652', '345771', '349202', '113801', '347467', '347079',
#        '237735', '315092', '383123', '112901', '315091', '2658',
#        'LP 1588', '368364', 'AQ/3. 30631', '28004', '350408', '347075',
#        '2654', '244368', '113790', 'SOTON/O.Q. 3101309', '236854',
#        'PC 17580', '2684', '349229', '110469', '244360', '2675', '2622',
#        'C.A. 15185', '350403', '348125', '237670', '2688', '248726',
#        'F.C.C. 13540', '113044', '1222', '368402', '315083', '112378',
#        'SC/PARIS 2147', '28133', '248746', '315152', '29107', '680',
#        '366713', '330910', 'SC/PARIS 2159', '349911', '244346', '364858',
#        'C.A. 30769', '371109', '347065', '21332', '17765',
#        'SC/PARIS 2166', '28666', '334915', '365237', '347086',
#        'A.5. 3236', 'SOTON/O.Q. 3101262', '359309'], dtype=object)

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# **New features created or to be created:**
# 1. Cabin_null, Age_null: is the value of Cabin or Age missing? 0 = No, 1 = Yes.
# 2. Title_group (groups based on the titles extracted from 'Name'): described in the notebook 'Dealing with missing values'.
# 3. Family_size: the number of family members on board, the addition of SibSp and Parch.
# 4. 'Ticket_group_size': the sizes of the groups sharing the ticket numbers.
# 5. 'Last_name', 'Ori_last_name'

# %% [markdown]
# ### Create 'Cabin_null' and 'Age_null' features

# %%
full_df['Cabin_null'] = full_df['Cabin'].isnull()
full_df['Age_null'] = full_df['Age'].isnull()

# %% [markdown]
# ### Create 'Title' and 'Title_group' features

# %%
#create 'Title' feature
full_df['Title'] = full_df['Name'].str.extract('([A-Za-z]+)\.', expand=False)
#check for null values
full_df.Title.isnull().sum()
# Out:
# 0

# %%
#create 'Title_group' feature
#convert the title value from 'Dr' to 'Dr (female)' for the female 
full_df.loc[(full_df.Title=='Dr') & (full_df.Is_female == 1), 'Title'] = 'Dr (female)'

#group the titles to combine as many rare titles with the common ones as possible
#based on the title definitions and the sex information of the dataset
#rare titles are those in less than 10 samples
title_groups = {'male adult': ['Mr', 'Don', 'Rev', 'Dr',  'Sir', 'Major',  'Col', 'Capt', 'Countess', 'Jonkheer'],
                'boy': ['Master'],
                'girl or unmarried woman': ['Miss'],
               'married woman': ['Mrs', 'Dona', 'Mme', 'Mlle'],
               'girl or woman (married or not)': ['Ms', 'Lady', 'Dr (female)']}

full_df['Title_group'] = full_df['Title']

for k in title_groups:
    full_df['Title_group'].replace(title_groups[k], k, inplace=True)
    
full_df['Title_group'].value_counts()
# Out:
# male adult                        783
# girl or unmarried woman           260
# married woman                     201
# boy                                61
# girl or woman (married or not)      4
# Name: Title_group, dtype: int64

# %% [markdown]
# ### Create 'Family_size' and 'Family_name' features

# %%
# the family includes the passenger and their sisters, brothers, parents and children
# create 'Family_size' feature
full_df['Family_size'] = full_df['SibSp'] + full_df['Parch'] + 1
print("{} passengers accompanied by family members".format(sum(full_df['Family_size']!=1)))
# Out:
# 517 passengers accompanied by family members

# %%
# create 'Family_name' feature
full_df['Family_name'] = full_df['Name'].str.extract('([A-Za-z]+)\,', expand=False)

# %%
family_name_sizes = full_df.groupby('Family_name')['PassengerId'].count()
family_name_sizes.value_counts()
# Out:
# 1     633
# 2     133
# 3      63
# 4      23
# 6       9
# 5       6
# 11      2
# 8       2
# 7       1
# Name: PassengerId, dtype: int64

# %%
full_df['Family_name_size'] = full_df['Family_name'].apply(lambda x: family_name_sizes[x])

# %%
are_sizes_unequal = full_df['Family_name_size']!=full_df['Family_size']
print('{:.0f}% records have unequal Family_name_size and Family_size values'.format(are_sizes_unequal.sum()/len(full_df)*100))
# Out:
# 26% records have unequal Family_name_size and Family_size values

# %%
columns = ['PassengerId', 'Name', 'Family_size', 'Family_name', 'Family_name_size', 'Pclass', 'Age', \
           'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Ticket_group_size', 'Title_group']
full_df.sort_values(by=['Family_name', 'PassengerId']).loc[are_sizes_unequal, columns]
# Out:
#       PassengerId                                            Name  \
# 948           949                   Abelseth, Mr. Olaus Jorgensen
# 1236         1237                     Abelseth, Miss. Karen Marie
# 40             41  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 210           211                                  Ali, Mr. Ahmed
# 784           785                                Ali, Mr. William
# ...           ...                                             ...
# 914           915                 Williams, Mr. Richard Norris II
# 555           556                              Wright, Mr. George
# 1053         1054                            Wright, Miss. Marion
# 1027         1028                       Zakarian, Mr. Mapriededer
# 1062         1063                             Zakarian, Mr. Ortin
#
#       Family_size Family_name  Family_name_size  Pclass   Age  SibSp  Parch  \
# 948             1    Abelseth                 2       3  25.0      0      0
# 1236            1    Abelseth                 2       3  16.0      0      0
# 40              2       Ahlin                 1       3  40.0      1      0
# 210             1         Ali                 2       3  24.0      0      0
# 784             1         Ali                 2       3  25.0      0      0
# ...           ...         ...               ...     ...   ...    ...    ...
# 914             2    Williams                 5       1  21.0      0      1
# 555             1      Wright                 2       1  62.0      0      0
# 1053            1      Wright                 2       2  26.0      0      0
# 1027            1    Zakarian                 2       3  26.5      0      0
# 1062            1    Zakarian                 2       3  27.0      0      0
#
#                   Ticket     Fare  Cabin Embarked  Ticket_group_size  \
# 948               348122   7.6500  F G63        S                  1
# 1236              348125   7.6500    NaN        S                  1
# 40                  7546   9.4750    NaN        S                  1
# 210   SOTON/O.Q. 3101311   7.0500    NaN        S                  1
# 784   SOTON/O.Q. 3101312   7.0500    NaN        S                  1
# ...                  ...      ...    ...      ...                ...
# 914             PC 17597  61.3792    NaN        C                  2
# 555               113807  26.5500    NaN        S                  1
# 1053              220844  13.5000    NaN        S                  1
# 1027                2656   7.2250    NaN        C                  1
# 1062                2670   7.2250    NaN        C                  1
#
#                   Title_group
# 948                male adult
# 1236  girl or unmarried woman
# 40              married woman
# 210                male adult
# 784                male adult
# ...                       ...
# 914                male adult
# 555                male adult
# 1053  girl or unmarried woman
# 1027               male adult
# 1062               male adult
#
# [346 rows x 15 columns]

# %%
pd.crosstab(full_df['Family_size'], full_df['Survived'], normalize='index').plot(kind='bar', stacked=True, title="Survived by family size")
# Out:
# <AxesSubplot:title={'center':'Survived by family size'}, xlabel='Family_size'>

# %%
pd.crosstab(full_df['Family_size'], full_df['Survived'], normalize='index')
# Out:
# Survived          0.0       1.0
# Family_size
# 1            0.695167  0.304833
# 2            0.447205  0.552795
# 3            0.421569  0.578431
# 4            0.275862  0.724138
# 5            0.800000  0.200000
# 6            0.863636  0.136364
# 7            0.727273  0.272727
# 8            1.000000  0.000000
# 11           1.000000  0.000000

# %%
families_not_sharing_ticket = full_df[(full_df.Family_size !=1) & (full_df.Ticket_group_size == 1)]
print("{} passengers accompanied by family members did not share the tickets".format(len(families_not_sharing_ticket)))
print('5 among them:')
families_not_sharing_ticket.head()
# Out:
# 48 passengers accompanied by family members did not share the tickets
# 5 among them:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 40            41       0.0       3
# 69            70       0.0       3
# 104          105       0.0       3
# 113          114       0.0       3
#
#                                                Name   Age  SibSp  Parch  \
# 0                           Braund, Mr. Owen Harris  22.0      1      0
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.0      1      0
# 69                                Kink, Mr. Vincenz  26.0      2      0
# 104                  Gustafsson, Mr. Anders Vilhelm  37.0      2      0
# 113                         Jussila, Miss. Katriina  20.0      1      0
#
#         Ticket    Fare Cabin  ... Fare_mean  Is_female  Cabin_quantity  \
# 0    A/5 21171  7.2500   NaN  ...    7.2500          0               1
# 40        7546  9.4750   NaN  ...    9.4750          1               1
# 69      315151  8.6625   NaN  ...    8.6625          0               1
# 104    3101276  7.9250   NaN  ...    7.9250          0               1
# 113       4136  9.8250   NaN  ...    9.8250          1               1
#
#      Cabin_null  Age_null  Title              Title_group  Family_size  \
# 0          True     False     Mr               male adult            2
# 40         True     False    Mrs            married woman            2
# 69         True     False     Mr               male adult            3
# 104        True     False     Mr               male adult            3
# 113        True     False   Miss  girl or unmarried woman            2
#
#     Family_name Family_name_size
# 0        Braund                2
# 40        Ahlin                1
# 69         Kink                2
# 104  Gustafsson                4
# 113     Jussila                3
#
# [5 rows x 23 columns]

# %%
#obtain the number of companions who are not family members

# %%
full_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Is_train', 'Ticket_group_size',
#        'Fare_mean', 'Is_female', 'Cabin_quantity', 'Cabin_null', 'Age_null',
#        'Title', 'Title_group', 'Family_size', 'Family_name',
#        'Family_name_size'],
#       dtype='object')

# %%
#check the fares' distribution of Pclass1
pclass1_df = full_df[full_df.Pclass==1]
sns.swarmplot(x=pclass1_df['Fare']);

# %%
sns.swarmplot(x='Survived',y='Fare',hue='Is_female', data=pclass1_df);

# %%
sns.swarmplot(x='Survived',y='Fare',hue='Is_female', data=full_df[full_df.Pclass==2]);

# %%
sns.swarmplot(x='Survived',y='Fare',hue='Is_female', data=full_df[full_df.Pclass==3]);

# %%
compare_hists('Fare', df=pclass1_df)

# %%
pclass1_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Is_train', 'Ticket_group_size',
#        'Fare_mean', 'Is_female', 'Cabin_quantity', 'Cabin_null', 'Age_null',
#        'Title', 'Title_group', 'Family_size', 'Family_name',
#        'Family_name_size', 'Sub_pclass1'],
#       dtype='object')

# %%
pclass1_df[['Survived', 'Fare', 'Is_female', 'Ticket_group_size', 'Family_size', 'Age', 'SibSp', 'Parch', 'Embarked']].corr(method='spearman')
# Out:
#                    Survived      Fare  Is_female  Ticket_group_size  \
# Survived           1.000000  0.271062   0.615212           0.262306
# Fare               0.271062  1.000000   0.363552           0.923198
# Is_female          0.615212  0.363552   1.000000           0.371980
# Ticket_group_size  0.262306  0.923198   0.371980           1.000000
# Family_size        0.191275  0.517748   0.227433           0.538693
# Age               -0.267771 -0.182549  -0.156827          -0.207179
# SibSp              0.182559  0.399214   0.174850           0.405282
# Parch              0.081924  0.423082   0.154499           0.466727
#
#                    Family_size       Age     SibSp     Parch
# Survived              0.191275 -0.267771  0.182559  0.081924
# Fare                  0.517748 -0.182549  0.399214  0.423082
# Is_female             0.227433 -0.156827  0.174850  0.154499
# Ticket_group_size     0.538693 -0.207179  0.405282  0.466727
# Family_size           1.000000 -0.075890  0.779559  0.728673
# Age                  -0.075890  1.000000 -0.002925 -0.111962
# SibSp                 0.779559 -0.002925  1.000000  0.204105
# Parch                 0.728673 -0.111962  0.204105  1.000000

# %%
full_df.loc[full_df.Pclass==1, 'Sub_pclass1'] = 3

# %%
full_df.loc[full_df.Fare>=100, 'Sub_pclass1'] = 2

# %%
full_df.loc[full_df.Fare>=500, 'Sub_pclass1'] = 1

# %%
full_df.loc[(full_df.Pclass==1) & (full_df.Is_female==0), \
            ['Ticket_group_size', 'Family_size', 'Fare', 'Sub_pclass1', 'Survived']].corr(method='spearman')['Survived']
# Out:
# Ticket_group_size    0.002103
# Family_size          0.106627
# Fare                 0.026797
# Sub_pclass1         -0.008821
# Survived             1.000000
# Name: Survived, dtype: float64

# %%
full_df.loc[full_df.Fare.isin(range(100, 500)), 'Sub_pclass1'] = 1

# %%
#looking for parlor suite and adjacent cabins among the top 10 highest fares 
pclass1_df.sort_values(by=['Fare', 'Ticket'], ascending=False).head(30)[columns]
# Out:
#       PassengerId                                               Name  \
# 258           259                                   Ward, Miss. Anna
# 679           680                 Cardeza, Mr. Thomas Drake Martinez
# 737           738                             Lesurer, Mr. Gustave J
# 1234         1235  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 27             28                     Fortune, Mr. Charles Alexander
# 88             89                         Fortune, Miss. Mabel Helen
# 341           342                     Fortune, Miss. Alice Elizabeth
# 438           439                                  Fortune, Mr. Mark
# 944           945                         Fortune, Miss. Ethel Flora
# 960           961                Fortune, Mrs. Mark (Mary McDougald)
# 311           312                         Ryerson, Miss. Emily Borie
# 742           743              Ryerson, Miss. Susan Parker "Suzette"
# 915           916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 950           951                        Chaudanson, Miss. Victorine
# 955           956                        Ryerson, Master. John Borie
# 1033         1034                         Ryerson, Mr. Arthur Larned
# 1266         1267                           Bowen, Miss. Grace Scott
# 118           119                           Baxter, Mr. Quigg Edmond
# 299           300    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 1075         1076  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 380           381                              Bidois, Miss. Rosalie
# 557           558                                Robbins, Mr. Victor
# 700           701  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 716           717                      Endres, Miss. Caroline Louise
# 1093         1094                             Astor, Col. John Jacob
# 527           528                                 Farthing, Mr. John
# 972           973                                 Straus, Mr. Isidor
# 1005         1006             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 1047         1048                                  Bird, Miss. Ellen
# 377           378                          Widener, Mr. Harry Elkins
#
#       Family_size Family_name  Family_name_size  Pclass   Age  SibSp  Parch  \
# 258             1        Ward                 1       1  35.0      0      0
# 679             2     Cardeza                 2       1  36.0      0      1
# 737             1     Lesurer                 1       1  35.0      0      0
# 1234            2     Cardeza                 2       1  58.0      0      1
# 27              6     Fortune                 6       1  19.0      3      2
# 88              6     Fortune                 6       1  23.0      3      2
# 341             6     Fortune                 6       1  24.0      3      2
# 438             6     Fortune                 6       1  64.0      1      4
# 944             6     Fortune                 6       1  28.0      3      2
# 960             6     Fortune                 6       1  60.0      1      4
# 311             5     Ryerson                 5       1  18.0      2      2
# 742             5     Ryerson                 5       1  21.0      2      2
# 915             5     Ryerson                 5       1  48.0      1      3
# 950             1  Chaudanson                 1       1  36.0      0      0
# 955             5     Ryerson                 5       1  13.0      2      2
# 1033            5     Ryerson                 5       1  61.0      1      3
# 1266            1       Bowen                 2       1  45.0      0      0
# 118             2      Baxter                 2       1  24.0      0      1
# 299             2      Baxter                 2       1  50.0      0      1
# 1075            3     Douglas                 3       1  27.0      1      1
# 380             1      Bidois                 1       1  42.0      0      0
# 557             1     Robbins                 1       1   NaN      0      0
# 700             2       Astor                 2       1  18.0      1      0
# 716             1      Endres                 1       1  38.0      0      0
# 1093            2       Astor                 2       1  47.0      1      0
# 527             1    Farthing                 1       1   NaN      0      0
# 972             2      Straus                 2       1  67.0      1      0
# 1005            2      Straus                 2       1  63.0      1      0
# 1047            1        Bird                 1       1  29.0      0      0
# 377             3     Widener                 3       1  27.0      0      2
#
#         Ticket      Fare            Cabin Embarked  Ticket_group_size  \
# 258   PC 17755  512.3292              NaN        C                  4
# 679   PC 17755  512.3292      B51 B53 B55        C                  4
# 737   PC 17755  512.3292             B101        C                  4
# 1234  PC 17755  512.3292      B51 B53 B55        C                  4
# 27       19950  263.0000      C23 C25 C27        S                  6
# 88       19950  263.0000      C23 C25 C27        S                  6
# 341      19950  263.0000      C23 C25 C27        S                  6
# 438      19950  263.0000      C23 C25 C27        S                  6
# 944      19950  263.0000      C23 C25 C27        S                  6
# 960      19950  263.0000      C23 C25 C27        S                  6
# 311   PC 17608  262.3750  B57 B59 B63 B66        C                  7
# 742   PC 17608  262.3750  B57 B59 B63 B66        C                  7
# 915   PC 17608  262.3750  B57 B59 B63 B66        C                  7
# 950   PC 17608  262.3750              B61        C                  7
# 955   PC 17608  262.3750  B57 B59 B63 B66        C                  7
# 1033  PC 17608  262.3750  B57 B59 B63 B66        C                  7
# 1266  PC 17608  262.3750              NaN        C                  7
# 118   PC 17558  247.5208          B58 B60        C                  3
# 299   PC 17558  247.5208          B58 B60        C                  3
# 1075  PC 17558  247.5208          B58 B60        C                  3
# 380   PC 17757  227.5250              NaN        C                  5
# 557   PC 17757  227.5250              NaN        C                  5
# 700   PC 17757  227.5250          C62 C64        C                  5
# 716   PC 17757  227.5250              C45        C                  5
# 1093  PC 17757  227.5250          C62 C64        C                  5
# 527   PC 17483  221.7792              C95        S                  4
# 972   PC 17483  221.7792          C55 C57        S                  4
# 1005  PC 17483  221.7792          C55 C57        S                  4
# 1047  PC 17483  221.7792              C97        S                  4
# 377     113503  211.5000              C82        C                  5
#
#                   Title_group  Survived
# 258   girl or unmarried woman       1.0
# 679                male adult       1.0
# 737                male adult       1.0
# 1234            married woman       NaN
# 27                 male adult       0.0
# 88    girl or unmarried woman       1.0
# 341   girl or unmarried woman       1.0
# 438                male adult       0.0
# 944   girl or unmarried woman       NaN
# 960             married woman       NaN
# 311   girl or unmarried woman       1.0
# 742   girl or unmarried woman       1.0
# 915             married woman       NaN
# 950   girl or unmarried woman       NaN
# 955                       boy       NaN
# 1033               male adult       NaN
# 1266  girl or unmarried woman       NaN
# 118                male adult       0.0
# 299             married woman       1.0
# 1075            married woman       NaN
# 380   girl or unmarried woman       1.0
# 557                male adult       0.0
# 700             married woman       1.0
# 716   girl or unmarried woman       1.0
# 1093               male adult       NaN
# 527                male adult       0.0
# 972                male adult       NaN
# 1005            married woman       NaN
# 1047  girl or unmarried woman       NaN
# 377                male adult       0.0

# %%
pclass2_df = full_df[full_df.Pclass==2]
pclass2_df.sort_values(by=['Fare', 'Ticket'], ascending=False).head(50)[columns]
# Out:
#       PassengerId                                               Name  \
# 72             73                               Hood, Mr. Ambrose Jr
# 120           121                        Hickman, Mr. Stanley George
# 385           386                          Davies, Mr. Charles Henry
# 655           656                          Hickman, Mr. Leonard Mark
# 665           666                                 Hickman, Mr. Lewis
# 1103         1104                          Deacon, Mr. Percy William
# 1243         1244                                Dibden, Mr. William
# 615           616                                Herman, Miss. Alice
# 754           755                   Herman, Mrs. Samuel (Jane Laver)
# 1121         1122                        Sweet, Mr. George Frederick
# 1244         1245                                 Herman, Mr. Samuel
# 1276         1277                                 Herman, Miss. Kate
# 43             44           Laroche, Miss. Simonne Marie Anne Andree
# 608           609  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 685           686             Laroche, Mr. Joseph Philippe Lemercier
# 1187         1188                              Laroche, Miss. Louise
# 670           671  Brown, Mrs. Thomas William Solomon (Elizabeth ...
# 684           685                  Brown, Mr. Thomas William Solomon
# 1066         1067                          Brown, Miss. Edith Eileen
# 183           184                          Becker, Master. Richard F
# 618           619                        Becker, Miss. Marion Louise
# 1069         1070   Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 1217         1218                       Becker, Miss. Ruth Elizabeth
# 817           818                                 Mallet, Mr. Albert
# 827           828                              Mallet, Master. Andre
# 1252         1253            Mallet, Mrs. Albert (Antoinette Magnin)
# 145           146                       Nicholls, Mr. Joseph Charles
# 549           550                     Davies, Master. John Morgan Jr
# 1067         1068                               Sincock, Miss. Maude
# 1221         1222  Davies, Mrs. John Morgan (Elizabeth Agnes Mary...
# 596           597                         Leitch, Miss. Jessie Wills
# 720           721                  Harper, Miss. Annie Jessie "Nina"
# 848           849                                  Harper, Rev. John
# 416           417    Drew, Mrs. James Vivian (Lulu Thorne Christian)
# 1085         1086                      Drew, Master. Marshall Brines
# 1138         1139                             Drew, Mr. James Vivian
# 922           923                      Jefferys, Mr. Clifford Thomas
# 1210         1211                       Jefferys, Mr. Ernest Wilfred
# 1229         1230                               Denbury, Mr. Herbert
# 9              10                Nasser, Mrs. Nicholas (Adele Achem)
# 122           123                               Nasser, Mr. Nicholas
# 580           581                        Christy, Miss. Julie Rachel
# 1132         1133                      Christy, Mrs. (Alice Frances)
# 78             79                      Caldwell, Master. Alden Gates
# 323           324  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...
# 898           899                       Caldwell, Mr. Albert Francis
# 58             59                       West, Miss. Constance Mirium
# 450           451                              West, Mr. Edwy Arthur
# 472           473            West, Mrs. Edwy Arthur (Ada Mary Worth)
# 1141         1142                              West, Miss. Barbara J
#
#       Family_size Family_name  Family_name_size  Pclass    Age  SibSp  Parch  \
# 72              1        Hood                 1       2  21.00      0      0
# 120             3     Hickman                 3       2  21.00      2      0
# 385             1      Davies                 7       2  18.00      0      0
# 655             3     Hickman                 3       2  24.00      2      0
# 665             3     Hickman                 3       2  32.00      2      0
# 1103            1      Deacon                 1       2  17.00      0      0
# 1243            1      Dibden                 1       2  18.00      0      0
# 615             4      Herman                 4       2  24.00      1      2
# 754             4      Herman                 4       2  48.00      1      2
# 1121            1       Sweet                 1       2  14.00      0      0
# 1244            4      Herman                 4       2  49.00      1      2
# 1276            4      Herman                 4       2  24.00      1      2
# 43              4     Laroche                 4       2   3.00      1      2
# 608             4     Laroche                 4       2  22.00      1      2
# 685             4     Laroche                 4       2  25.00      1      2
# 1187            4     Laroche                 4       2   1.00      1      2
# 670             3       Brown                 6       2  40.00      1      1
# 684             3       Brown                 6       2  60.00      1      1
# 1066            3       Brown                 6       2  15.00      0      2
# 183             4      Becker                 4       2   1.00      2      1
# 618             4      Becker                 4       2   4.00      2      1
# 1069            4      Becker                 4       2  36.00      0      3
# 1217            4      Becker                 4       2  12.00      2      1
# 817             3      Mallet                 3       2  31.00      1      1
# 827             3      Mallet                 3       2   1.00      0      2
# 1252            3      Mallet                 3       2  24.00      1      1
# 145             3    Nicholls                 1       2  19.00      1      1
# 549             3      Davies                 7       2   8.00      1      1
# 1067            1     Sincock                 1       2  20.00      0      0
# 1221            3      Davies                 7       2  48.00      0      2
# 596             1      Leitch                 1       2    NaN      0      0
# 720             2      Harper                 4       2   6.00      0      1
# 848             2      Harper                 4       2  28.00      0      1
# 416             3        Drew                 3       2  34.00      1      1
# 1085            3        Drew                 3       2   8.00      0      2
# 1138            3        Drew                 3       2  42.00      1      1
# 922             3    Jefferys                 2       2  24.00      2      0
# 1210            3    Jefferys                 2       2  22.00      2      0
# 1229            1     Denbury                 1       2  25.00      0      0
# 9               2      Nasser                 2       2  14.00      1      0
# 122             2      Nasser                 2       2  32.50      1      0
# 580             3     Christy                 2       2  25.00      1      1
# 1132            3     Christy                 2       2  45.00      0      2
# 78              3    Caldwell                 3       2   0.83      0      2
# 323             3    Caldwell                 3       2  22.00      1      1
# 898             3    Caldwell                 3       2  26.00      1      1
# 58              4        West                 4       2   5.00      1      2
# 450             4        West                 4       2  36.00      1      2
# 472             4        West                 4       2  33.00      1      2
# 1141            4        West                 4       2   0.92      1      2
#
#                Ticket     Fare Cabin Embarked  Ticket_group_size  \
# 72       S.O.C. 14879  73.5000   NaN        S                  7
# 120      S.O.C. 14879  73.5000   NaN        S                  7
# 385      S.O.C. 14879  73.5000   NaN        S                  7
# 655      S.O.C. 14879  73.5000   NaN        S                  7
# 665      S.O.C. 14879  73.5000   NaN        S                  7
# 1103     S.O.C. 14879  73.5000   NaN        S                  7
# 1243     S.O.C. 14879  73.5000   NaN        S                  7
# 615            220845  65.0000   NaN        S                  5
# 754            220845  65.0000   NaN        S                  5
# 1121           220845  65.0000   NaN        S                  5
# 1244           220845  65.0000   NaN        S                  5
# 1276           220845  65.0000   NaN        S                  5
# 43      SC/Paris 2123  41.5792   NaN        C                  4
# 608     SC/Paris 2123  41.5792   NaN        C                  4
# 685     SC/Paris 2123  41.5792   NaN        C                  4
# 1187    SC/Paris 2123  41.5792   NaN        C                  4
# 670             29750  39.0000   NaN        S                  3
# 684             29750  39.0000   NaN        S                  3
# 1066            29750  39.0000   NaN        S                  3
# 183            230136  39.0000    F4        S                  4
# 618            230136  39.0000    F4        S                  4
# 1069           230136  39.0000    F4        S                  4
# 1217           230136  39.0000    F4        S                  4
# 817   S.C./PARIS 2079  37.0042   NaN        C                  3
# 827   S.C./PARIS 2079  37.0042   NaN        C                  3
# 1252  S.C./PARIS 2079  37.0042   NaN        C                  3
# 145        C.A. 33112  36.7500   NaN        S                  4
# 549        C.A. 33112  36.7500   NaN        S                  4
# 1067       C.A. 33112  36.7500   NaN        S                  4
# 1221       C.A. 33112  36.7500   NaN        S                  4
# 596            248727  33.0000   NaN        S                  3
# 720            248727  33.0000   NaN        S                  3
# 848            248727  33.0000   NaN        S                  3
# 416             28220  32.5000   NaN        S                  3
# 1085            28220  32.5000   NaN        S                  3
# 1138            28220  32.5000   NaN        S                  3
# 922        C.A. 31029  31.5000   NaN        S                  3
# 1210       C.A. 31029  31.5000   NaN        S                  3
# 1229       C.A. 31029  31.5000   NaN        S                  3
# 9              237736  30.0708   NaN        C                  2
# 122            237736  30.0708   NaN        C                  2
# 580            237789  30.0000   NaN        S                  2
# 1132           237789  30.0000   NaN        S                  2
# 78             248738  29.0000   NaN        S                  3
# 323            248738  29.0000   NaN        S                  3
# 898            248738  29.0000   NaN        S                  3
# 58         C.A. 34651  27.7500   NaN        S                  4
# 450        C.A. 34651  27.7500   NaN        S                  4
# 472        C.A. 34651  27.7500   NaN        S                  4
# 1141       C.A. 34651  27.7500   NaN        S                  4
#
#                   Title_group
# 72                 male adult
# 120                male adult
# 385                male adult
# 655                male adult
# 665                male adult
# 1103               male adult
# 1243               male adult
# 615   girl or unmarried woman
# 754             married woman
# 1121               male adult
# 1244               male adult
# 1276  girl or unmarried woman
# 43    girl or unmarried woman
# 608             married woman
# 685                male adult
# 1187  girl or unmarried woman
# 670             married woman
# 684                male adult
# 1066  girl or unmarried woman
# 183                       boy
# 618   girl or unmarried woman
# 1069            married woman
# 1217  girl or unmarried woman
# 817                male adult
# 827                       boy
# 1252            married woman
# 145                male adult
# 549                       boy
# 1067  girl or unmarried woman
# 1221            married woman
# 596   girl or unmarried woman
# 720   girl or unmarried woman
# 848                male adult
# 416             married woman
# 1085                      boy
# 1138               male adult
# 922                male adult
# 1210               male adult
# 1229               male adult
# 9               married woman
# 122                male adult
# 580   girl or unmarried woman
# 1132            married woman
# 78                        boy
# 323             married woman
# 898                male adult
# 58    girl or unmarried woman
# 450                male adult
# 472             married woman
# 1141  girl or unmarried woman
